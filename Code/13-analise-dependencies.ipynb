# %%
import pandas as pd
import ast
import matplotlib.pyplot as plt
import os

# Caminho para a pasta de CSVs
csv_folder_path = '../Database/Questao3/Repositorios'

# Carregar a lista de repositórios do CSV
repos_list_csv = pd.read_csv('../Database/Resultados-Busca/repositories.csv')

# Supondo que a coluna com o nome dos repositórios seja 'repo_name'
# Substituir '/' por '_' e adicionar o sufixo para coincidir com o padrão dos arquivos
repos_list = {repo.replace("/", "_") + "_package_json_history" for repo in repos_list_csv['name'].tolist()}

# Obter a lista de arquivos na pasta de CSVs (removendo a extensão .csv)
generated_csvs = {os.path.splitext(file)[0] for file in os.listdir(csv_folder_path) if file.endswith('.csv')}
repositorios_list = list(generated_csvs)
# Substituindo "_package_json_history" e "_" por "/" em cada elemento da lista
repositorios_list_modified = [repo.replace("_package_json_history", "").replace("_", "/") for repo in repositorios_list]

# Lista para armazenar dados de análise final
final_analysis_data = []

# Função para salvar o gráfico
def save_plot(x, y1, y2, x_label, title, filename, plot_type):
    plt.figure(figsize=(14, 7))
    plt.plot(x, y1, label='Dependências', marker='o', color='blue', markersize=8)
    plt.plot(x, y2, label='DevDependências', marker='o', color='orange', markersize=8)

    plt.title(title, fontsize=16)
    plt.xlabel(x_label, fontsize=14)
    plt.ylabel('Número de Dependências', fontsize=14)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1), frameon=True, framealpha=1, edgecolor='black', facecolor='white')
    plt.tight_layout()

    # Definir o diretório de salvamento com base no tipo de gráfico
    if plot_type == 'date':
        save_path = "../Image/Questao3/Date"
    elif plot_type == 'commit':
        save_path = "../Image/Questao3/Commit"
    else:
        raise ValueError("Tipo de gráfico inválido. Use 'date' ou 'commit'.")

    os.makedirs(save_path, exist_ok=True)  # Cria o diretório se não existir
    plt.savefig(f"{save_path}/{filename}.png")
    plt.close()  # Fecha a figura para liberar memória

# Iterar sobre cada repositório listado
for i in range(len(repositorios_list)):  # Garante que não ultrapasse o tamanho da lista
    repo_name = repositorios_list[i]
    name = repositorios_list_modified[i]
    # Carregar os dados
    path = f'{csv_folder_path}/{repo_name}.csv'

    if not os.path.exists(path):
        print(f"Arquivo não encontrado: {path}")
        continue  # Pula para o próximo repositório se o arquivo não existir

    df = pd.read_csv(path)

    # Verificar se as colunas necessárias existem
    if not all(col in df.columns for col in ['date', 'commit', 'dependencies_changes', 'dev_dependencies_changes']):
        print(f"Colunas necessárias ausentes no arquivo: {repo_name}.csv")
        continue

    # Converter a coluna 'date' para o tipo datetime
    df['date'] = pd.to_datetime(df['date'])

    # Criar conjuntos para rastrear todas as bibliotecas
    all_dependencies = set()
    all_dev_dependencies = set()

    # Criar um DataFrame para armazenar a evolução
    evolution_data = []

    # Função para converter string em dicionário com tratamento de exceção
    def safe_literal_eval(s):
        try:
            return ast.literal_eval(s)
        except (ValueError, SyntaxError):
            return {'added': [], 'removed': []}

    df['dependencies_changes'] = df['dependencies_changes'].apply(safe_literal_eval)
    df['dev_dependencies_changes'] = df['dev_dependencies_changes'].apply(safe_literal_eval)

    # Iterar sobre as mudanças
    for index, data_row in df.iterrows():
        # Adicionando mudanças de dependências
        dependencies_added = data_row['dependencies_changes'].get('added', [])
        dependencies_removed = data_row['dependencies_changes'].get('removed', [])

        dev_dependencies_added = data_row['dev_dependencies_changes'].get('added', [])
        dev_dependencies_removed = data_row['dev_dependencies_changes'].get('removed', [])

        # Atualizar conjuntos de bibliotecas
        all_dependencies.update(dependencies_added)
        all_dependencies.difference_update(dependencies_removed)

        all_dev_dependencies.update(dev_dependencies_added)
        all_dev_dependencies.difference_update(dev_dependencies_removed)

        # Armazenar evolução
        evolution_data.append({
            'commit': data_row['commit'],
            'date': data_row['date'],
            'current_dependencies': list(all_dependencies),
            'current_dev_dependencies': list(all_dev_dependencies),
            'current_dependencies_count': len(all_dependencies),
            'current_dev_dependencies_count': len(all_dev_dependencies),
        })

    # Criar DataFrame de evolução
    evolution_df = pd.DataFrame(evolution_data)

    # Gráfico da evolução das dependências ao longo do tempo
    save_plot(evolution_df['date'], evolution_df['current_dependencies_count'], evolution_df['current_dev_dependencies_count'],
              'Data', f'Evolução das Dependências e DevDependências ao longo do Tempo - ({name})', f'{repo_name}_evolucao_dependencias_tempo', 'date')

    # Gráfico da evolução das dependências ao longo dos commits
    save_plot(evolution_df['commit'], evolution_df['current_dependencies_count'], evolution_df['current_dev_dependencies_count'],
              'Commits', f'Evolução das Dependências e DevDependências ao longo dos Commits - ({name})', f'{repo_name}_evolucao_dependencias_commits', 'commit')

    # Análise final
    total_unique_dependencies = len(all_dependencies)
    total_unique_dev_dependencies = len(all_dev_dependencies)

    print(f'Total de dependências únicas: {total_unique_dependencies}')
    print(f'Total de devDependências únicas: {total_unique_dev_dependencies}')

    # Verificar se as mesmas bibliotecas estiveram presentes sempre
    if not evolution_df['current_dependencies'].empty:
        always_present_dependencies = set.intersection(*(set(x) for x in evolution_df['current_dependencies']))
    else:
        always_present_dependencies = set()

    if not evolution_df['current_dev_dependencies'].empty:
        always_present_dev_dependencies = set.intersection(*(set(x) for x in evolution_df['current_dev_dependencies']))
    else:
        always_present_dev_dependencies = set()

    print(f'Dependências sempre presentes: {always_present_dependencies}')
    print(f'DevDependências sempre presentes: {always_present_dev_dependencies}')

    # Armazenar dados de análise final
    final_analysis_data.append({
        'repo_name': repo_name,
        'total_unique_dependencies': total_unique_dependencies,
        'total_unique_dev_dependencies': total_unique_dev_dependencies,
        'always_present_dependencies': ', '.join(always_present_dependencies),
        'always_present_dev_dependencies': ', '.join(always_present_dev_dependencies)
    })


# Criar um DataFrame com os dados de análise final
final_analysis_df = pd.DataFrame(final_analysis_data)

# Salvar o DataFrame como um arquivo CSV
final_analysis_df.to_csv('../Database/Questao3/final_analysis.csv', index=False)
# Out:
# Total de dependências únicas: 7
# Total de devDependências únicas: 5
# Dependências sempre presentes: {'react', 'react-native'}
# DevDependências sempre presentes: set()
# Total de dependências únicas: 0
# Total de devDependências únicas: 44
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 20
# Total de devDependências únicas: 29
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'style-loader', 'rucksack-css', 'sass-loader', 'autoprefixer'}
# Total de dependências únicas: 12
# Total de devDependências únicas: 17
# Dependências sempre presentes: {'assets', 'recorder.js', 'main.js', 'recorderjs', 'stats.js', 'main', 'recorder', 'dat.gui', 'howler'}
# DevDependências sempre presentes: {'babel-preset-env', 'webpack-cli', 'eslint', 'babel-preset-react', 'clang-format', 'cross-env', 'eslint-config-google', 'babel-preset-es2015', '@tensorflow-models/posenet', 'babel-polyfill', 'babel-preset-es2017', 'parcel-bundler', 'babel-core', 'dat.gui', 'babel-plugin-transform-runtime', 'webpack', '@tensorflow/tfjs'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 0
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 4
# Total de devDependências únicas: 10
# Dependências sempre presentes: {'react', 'react-dom'}
# DevDependências sempre presentes: {'webpack-cli', 'css-loader', '@babel/preset-env', '@babel/preset-react', 'babel-loader', 'style-loader', 'webpack', '@babel/core', 'html-webpack-plugin', 'webpack-dev-server'}
# Total de dependências únicas: 1
# Total de devDependências únicas: 16
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 16
# Total de devDependências únicas: 6
# Dependências sempre presentes: {'react', 'react-native', 'expo', 'react-native-gesture-handler', 'react-native-reanimated', 'faker', '@react-navigation/bottom-tabs', 'react-native-web', '@react-navigation/native', '@react-native-community/masked-view', 'react-native-safe-area-context', 'react-native-screens', '@react-navigation/drawer', '@react-navigation/stack', 'react-dom', '@react-navigation/material-top-tabs'}
# DevDependências sempre presentes: {'@types/faker', 'babel-preset-expo', 'typescript', '@types/react', '@babel/core', '@types/react-native'}
# Total de dependências únicas: 3
# Total de devDependências únicas: 6
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 5
# Total de devDependências únicas: 13
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'eslint'}
# Total de dependências únicas: 1
# Total de devDependências únicas: 31
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'react', 'nedb', 'react-redux', 'webpack', 'reselect', '@fluentui/react', 'webpack-cli', 'redux-thunk', 'react-dom', 'redux-devtools', 'typescript', 'html-webpack-plugin', 'electron-react-devtools', '@types/react-redux', 'electron', '@types/react-dom', 'redux', 'ts-loader', '@types/nedb', '@types/react'}
# Total de dependências únicas: 24
# Total de devDependências únicas: 10
# Dependências sempre presentes: {'invariant', 'react-static-container', 'fbemitter', 'mirror-creator', 'hoist-non-react-statics', 'react-redux', 'core-decorators', 'lodash', 'redux', 'warning', 'uuid-js', 'react-clone-referenced-element', 'reselect', 'redux-batched-actions'}
# DevDependências sempre presentes: set()
# Total de dependências únicas: 8
# Total de devDependências únicas: 27
# Dependências sempre presentes: {'@uswds/uswds'}
# DevDependências sempre presentes: {'eleventy-plugin-svg-sprite', 'postcss-cli', 'markdown-it-anchor', 'netlify-cms-proxy-server', 'npm-run-all', 'chokidar-cli', 'rimraf', '@11ty/eleventy-navigation', 'postcss', '@11ty/eleventy-plugin-rss', 'js-yaml', 'markdown-it', '@11ty/eleventy'}
# Total de dependências únicas: 13
# Total de devDependências únicas: 8
# Dependências sempre presentes: {'react', 'react-native'}
# DevDependências sempre presentes: {'babel-jest', 'react-test-renderer', 'eslint', '@react-native-community/eslint-config', '@babel/runtime', 'metro-react-native-babel-preset', '@babel/core', 'jest'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 0
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 0
# Total de devDependências únicas: 154
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'vue-template-compiler', 'css-loader', 'rollup-plugin-progress', 'webpack-merge', 'babelrc-rollup', 'vue-router', '@types/eslint-plugin-prettier', 'webpack', 'nib', 'aesir-cli', 'opn', 'stylus-loader', 'file-loader', 'eslint-plugin-promise', 'gulp-stylus', 'express', 'rollup-plugin-inject', 'vue-loader', 'connect-history-api-fallback', 'rollup-plugin-stylus-css-modules', 'stylus', 'rollup-plugin-babel', 'rollup-plugin-glob-import', 'git-user-email', '@types/babel-types', 'babel-eslint', 'rollup-plugin-node-resolve', 'rollup-plugin-json', 'cross-spawn', 'chai', 'rollup-plugin-alias', 'url-loader', 'commitizen', 'fastclick', 'inject-loader', 'ora', 'eslint-config-aesir-recommand', 'eslint-plugin-node', 'babel-register', 'rollup-plugin-node-globals', 'gulp-babel', 'cross-env', 'eslint-plugin-prettier', 'livereload', 'babel-core', 'gulp-base64', 'cssnano', 'eslint', 'rollup-plugin-commonjs', 'sinon', 'rollup-plugin-require-context', 'poststylus', 'vueify', 'friendly-errors-webpack-plugin', 'webpack-dev-middleware', 'fs-extra', 'optimize-css-assets-webpack-plugin', 'eslint-loader', 'rollup-plugin-node-builtins', 'http-proxy-middleware', 'babylon', '@types/prettier', 'rimraf', 'eslint-plugin-json', 'portfinder', 'eslint-plugin-standard', 'webpack-bundle-analyzer', 'eventsource-polyfill', 'babel-plugin-transform-runtime', 'commander', 'recursive-copy', 'semver', 'merge2', '@types/glob', 'word-wrap', 'eslint-plugin-html', 'moment', 'gulp', 'copy-webpack-plugin', 'glob', '@types/vue', 'prettier', 'babel-preset-env', 'postcss-pxtorem', 'vue', 'mime-types', 'autoprefixer', 'rollup-plugin-vue', 'rollup-pluginutils', 'gulp-preprocess', 'postcss-loader', 'babel-plugin-import', 'lint-staged', 'babel-plugin-istanbul', 'husky', 'rollup-plugin-css-only', 'dependency-tree', 'eslint-plugin-import', 'inquirer', 'progress-bar-webpack-plugin', 'babel-loader', 'babel-helper-vue-jsx-merge-props', 'rollup-plugin-filesize', 'git-user-name', 'webpack-hot-middleware', 'rollup-plugin-import-alias', 'postcss-url', 'chalk', 'gulp-util', 'bluebird', 'rollup', 'rollup-plugin-url', 'sinon-chai', 'eslint-config-standard', 'extract-text-webpack-plugin', 'html-webpack-plugin', 'svg-sprite-loader', 'rollup-plugin-image', 'rollup-plugin-uglify', 'babel-types', 'shelljs', 'vue-style-loader', 'babel-generator', 'selenium-server', '@types/babylon', 'eslint-config-aesir-mandatory', 'eslint-friendly-formatter', 'rollup-plugin-postcss', 'rollup-plugin-replace', 'rollup-plugin-template-html', '@types/babel-generator'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 19
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'npm-run-all'}
# Total de dependências únicas: 1
# Total de devDependências únicas: 0
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 9
# Total de devDependências únicas: 88
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'react', 'cz-conventional-changelog', '@types/react-test-renderer', '@babel/plugin-transform-runtime', 'file-loader', '@types/react-transition-group', '@types/jest-axe', '@babel/plugin-transform-modules-commonjs', 'react-dom', '@storybook/react', 'prismjs', 'typescript', 'prettier', 'jest-junit', 'lerna', 'mkdirp', '@types/chroma-js', '@types/lodash', 'npm-run-all', '@types/react-dom', '@storybook/components', '@babel/preset-env', '@types/node', 'rimraf', '@babel/preset-typescript', 'ts-loader', 'node-fetch', '@babel/preset-react', 'lint-staged', '@types/react', 'husky', 'jest'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 0
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 5
# Total de devDependências únicas: 0
# Dependências sempre presentes: {'react', 'react-dom', 'react-router-dom', 'react-scripts'}
# DevDependências sempre presentes: set()
# Total de dependências únicas: 1
# Total de devDependências únicas: 9
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'webpack-cli', 'ts-loader', 'typescript', 'webpack', 'html-webpack-plugin', 'webpack-dev-server'}
# Total de dependências únicas: 39
# Total de devDependências únicas: 23
# Dependências sempre presentes: {'react', 'react-native', 'expo', 'expo-status-bar', 'react-dom', 'react-native-web'}
# DevDependências sempre presentes: {'@types/react-dom', '@types/react', 'typescript', '@types/react-native', '@babel/core'}
# Total de dependências únicas: 4
# Total de devDependências únicas: 18
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'lerna'}
# Total de dependências únicas: 2
# Total de devDependências únicas: 13
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 10
# Total de devDependências únicas: 37
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'prettier', 'vite', 'vue', 'eslint', 'rimraf', 'lerna', 'lint-staged', '@commitlint/config-conventional'}
# Total de dependências únicas: 33
# Total de devDependências únicas: 14
# Dependências sempre presentes: {'react-helmet', 'gatsby-image', 'react', 'gatsby-source-filesystem', 'gatsby-plugin-react-helmet', 'gatsby', 'gatsby-transformer-sharp', 'gatsby-plugin-sharp', 'prop-types', 'react-dom', 'gatsby-plugin-manifest', 'gatsby-plugin-offline'}
# DevDependências sempre presentes: {'prettier'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 2
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 0
# Total de devDependências únicas: 0
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 0
# Total de devDependências únicas: 12
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 0
# Total de devDependências únicas: 24
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 0
# Total de devDependências únicas: 1
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'sass'}
# Total de dependências únicas: 9
# Total de devDependências únicas: 33
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'vite', 'less', '@vue/compiler-sfc'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 42
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 4
# Total de devDependências únicas: 31
# Dependências sempre presentes: {'@babel/runtime'}
# DevDependências sempre presentes: {'eslint-config-airbnb', 'eslint-plugin-import', 'eslint-plugin-react-hooks', 'less', 'css-loader', 'mini-css-extract-plugin', 'babel-loader', 'prettier-loader', 'webpack', 'less-loader', 'eslint-import-resolver-alias', '@babel/plugin-transform-runtime', 'eslint', '@babel/plugin-proposal-class-properties', 'eslint-plugin-jsx-a11y', 'prettier', 'eslint-plugin-react', 'babel-eslint', 'terser-webpack-plugin', 'eslint-config-prettier', 'optimize-css-assets-webpack-plugin', 'style-loader', 'eslint-loader', '@babel/core', '@babel/runtime-corejs3', '@babel/preset-env', '@babel/preset-react'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 24
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'merge-stream', 'gulp-add', 'through2', 'gulp-uglify', 'gulp-babel', 'browserify', 'gulp-debug', 'gulp-concat', 'gulp', 'gulp-if', 'gulp-rename', 'gulp-sourcemaps', 'jquery', 'vinyl-buffer', 'vinyl-source-stream', 'del'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 0
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 0
# Total de devDependências únicas: 30
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 7
# Total de devDependências únicas: 50
# Dependências sempre presentes: {'query-string', 'md5', 'react-native-vector-icons'}
# DevDependências sempre presentes: {'babel-cli', 'react', 'eslint-plugin-import', 'babel-preset-es2015', 'babel-polyfill', 'json-loader', 'babel-core', 'babel-loader', 'webpack', 'http-server', 'file-loader', 'react-test-renderer', 'eslint', 'gulp', 'react-dom', 'eslint-plugin-jsx-a11y', 'react-native-mock', 'babel-preset-react-native', 'gulp-replace', 'rsg-alt', 'prettier', 'babel-jest', 'eslint-plugin-react', 'babel-eslint', 'raw-loader', 'react-native-web', 'string-replace-webpack-plugin', 'babel-preset-stage-0', 'babel-plugin-add-module-exports', 'enzyme', 'webpack-dev-server', 'url-loader', 'estraverse-fb', 'jest', 'babel-register', 'babel-preset-react-optimize'}
# Total de dependências únicas: 3
# Total de devDependências únicas: 51
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'react', 'react-is', '@types/react-dom', 'react-dom', 'ts-loader', 'tslib', 'babel-loader', 'react-docgen-typescript-loader', 'tsdx', 'typescript', '@types/react', '@babel/core', 'husky'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 23
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 4
# Total de devDependências únicas: 40
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'prettier', 'eslint-config-airbnb-typescript', '@typescript-eslint/eslint-plugin', 'eslint-plugin-react', 'eslint', '@typescript-eslint/parser', 'eslint-plugin-prettier', 'eslint-plugin-react-hooks', 'eslint-config-airbnb', 'eslint-plugin-import', 'eslint-plugin-jsx-a11y', 'eslint-config-prettier', 'typescript', 'eslint-import-resolver-typescript'}
# Total de dependências únicas: 1
# Total de devDependências únicas: 14
# Dependências sempre presentes: {'lodash'}
# DevDependências sempre presentes: {'prettier', 'eslint', 'babel-eslint', 'lint-staged', 'husky'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 16
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'@size-limit/preset-small-lib', 'react', '@types/react-dom', '@react-native-community/netinfo', 'react-dom', '@types/react-native', 'swr', 'tslib', 'size-limit', 'eslint-config-nando', 'tsdx', 'typescript', '@react-navigation/native', '@types/react', 'husky'}
# Total de dependências únicas: 2
# Total de devDependências únicas: 34
# Dependências sempre presentes: {'@commitlint/config-conventional', '@commitlint/cli'}
# DevDependências sempre presentes: {'prettier', '@babel/plugin-transform-runtime', 'eslint-plugin-react', 'eslint', 'eslint-plugin-mdx', 'react-test-renderer', '@babel/runtime', '@babel/preset-env', 'eslint-plugin-prettier', 'babel-eslint', 'lerna', '@babel/preset-react', 'pretty-quick', 'eslint-config-prettier', '@babel/core', 'husky', 'jest'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 10
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'load-grunt-tasks', 'grunt-banner', 'grunt-contrib-concat', 'grunt-browserify', 'grunt-contrib-copy', 'grunt-contrib-watch', 'grunt-contrib-uglify', 'grunt-contrib-clean', 'grunt-babel'}
# Total de dependências únicas: 12
# Total de devDependências únicas: 55
# Dependências sempre presentes: {'electron-updater', '@electron-toolkit/preload', 'electron-log', 'mime-types', 'mkdirp', 'electron-store', '@electron-toolkit/utils'}
# DevDependências sempre presentes: {'react', 'string-width', 'slate', 'slate-react', 'remark-math', 'diacritics', 'vite-plugin-commonjs-externals', '@ant-design/icons', 'slate-history', 'unified', 'vite', 'nanoid', 'react-dom', 'rxjs', 'katex', 'typescript', '@vitejs/plugin-react', 'react-use', 'antd', 'prettier', 'tailwindcss', 'electron-vite', '@electron-toolkit/tsconfig', 'dexie', '@electron/notarize', 'slate-hyperscript', 'mermaid', 'remark-gfm', 'mobx-react-lite', 'electron', 'framer-motion', 'electron-builder', '@types/react-dom', 'remark-parse', '@types/node', 'sass', 'postcss', '@types/react', 'mobx', 'dayjs', '@types/mime-types'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 4
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 0
# Total de devDependências únicas: 0
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 0
# Total de devDependências únicas: 2
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 52
# Total de devDependências únicas: 39
# Dependências sempre presentes: {'react', 'react-dom', 'postcss', 'autoprefixer', 'next'}
# DevDependências sempre presentes: set()
# Total de dependências únicas: 0
# Total de devDependências únicas: 0
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 1
# Total de devDependências únicas: 10
# Dependências sempre presentes: {'ramda'}
# DevDependências sempre presentes: {'standard', 'babel-eslint'}
# Total de dependências únicas: 14
# Total de devDependências únicas: 63
# Dependências sempre presentes: {'vue-lodash', 'vue', 'vuex', 'lodash', 'vue-router'}
# DevDependências sempre presentes: {'vue-template-compiler', 'css-loader', 'semver', 'webpack-merge', 'babel-loader', 'webpack', 'file-loader', 'chalk', 'copy-webpack-plugin', 'vue-loader', 'html-webpack-plugin', 'autoprefixer', 'shelljs', 'friendly-errors-webpack-plugin', 'optimize-css-assets-webpack-plugin', 'style-loader', 'vue-style-loader', 'http-proxy-middleware', 'node-sass', 'url-loader', 'ora', 'rimraf', 'portfinder', 'webpack-bundle-analyzer', 'sass-loader'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 10
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 4
# Total de devDependências únicas: 45
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'balm', 'vue-loader'}
# Total de dependências únicas: 7
# Total de devDependências únicas: 4
# Dependências sempre presentes: {'react', 'react-native'}
# DevDependências sempre presentes: {'babel-preset-react-native', 'babel-jest', 'react-test-renderer', 'jest'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 6
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'semantic-release', '@semantic-release/git', '@semantic-release/changelog', '@saithodev/semantic-release-backmerge'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 92
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 33
# Total de devDependências únicas: 67
# Dependências sempre presentes: {'react', '@radix-ui/react-label', '@radix-ui/react-tooltip', '@tanstack/react-table', 'pino-pretty', '@spotlightjs/spotlight', '@radix-ui/react-icons', 'next-intl', 'pino', 'clsx', 'react-dom', '@radix-ui/react-slot', '@sentry/nextjs', 'class-variance-authority', 'drizzle-orm', '@radix-ui/react-dropdown-menu', '@logtail/pino', '@clerk/localizations', '@radix-ui/react-accordion', '@clerk/nextjs', '@hookform/resolvers', 'sharp', 'react-hook-form', 'zod', '@t3-oss/env-nextjs', 'lucide-react', 'next', 'tailwind-merge'}
# DevDependências sempre presentes: {'@storybook/addon-links', 'eslint-plugin-testing-library', 'cross-env', 'eslint-plugin-react-hooks', 'storybook', '@playwright/test', '@semantic-release/git', 'cssnano', '@storybook/test-runner', 'http-server', '@commitlint/cli', '@faker-js/faker', '@commitlint/cz-commitlint', 'eslint', 'eslint-plugin-jsx-a11y', 'start-server-and-test', '@storybook/react', 'typescript', 'tailwindcss', '@storybook/blocks', '@semantic-release/changelog', 'semantic-release', 'eslint-plugin-playwright', '@storybook/addon-essentials', 'autoprefixer', '@commitlint/config-conventional', '@percy/playwright', '@storybook/nextjs', 'eslint-plugin-jest-dom', 'commitizen', '@storybook/addon-interactions', '@storybook/test', 'npm-run-all', '@types/node', '@next/bundle-analyzer', 'drizzle-kit', '@testing-library/react', 'postcss', 'rimraf', 'dotenv-cli', 'lint-staged', 'eslint-plugin-tailwindcss', '@testing-library/jest-dom', '@types/react', '@percy/cli', 'eslint-plugin-simple-import-sort', 'husky'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 19
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'prettier', 'eslint-plugin-react', 'eslint', 'eslint-plugin-promise', 'eslint-plugin-jsx-a11y', 'babel-eslint', 'pretty-quick', 'lint-staged', '@upstatement/eslint-config', 'eslint-config-prettier', 'husky', '@upstatement/prettier-config'}
# Total de dependências únicas: 1
# Total de devDependências únicas: 3
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'typescript'}
# Total de dependências únicas: 23
# Total de devDependências únicas: 57
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'typescript'}
# Total de dependências únicas: 6
# Total de devDependências únicas: 5
# Dependências sempre presentes: {'react-navigation-transitions', 'react-navigation-fluid-transitions', 'react', 'react-native', 'react-navigation', '@babel/runtime'}
# DevDependências sempre presentes: {'babel-jest', 'react-test-renderer', 'metro-react-native-babel-preset', '@babel/core', 'jest'}
# Total de dependências únicas: 8
# Total de devDependências únicas: 61
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'html-loader', 'vue-hot-reload-api', 'less', 'css-loader', 'vue-router', 'babel-core', 'babel-loader', 'webpack', 'less-loader', 'file-loader', 'eslint', 'gulp-rename', 'gulp', 'vue-loader', 'extract-text-webpack-plugin', 'babel-runtime', 'vue-html-loader', 'style-loader', 'vue-style-loader', 'url-loader', 'autoprefixer-loader', 'babel-plugin-transform-runtime', 'gulp-less'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 22
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'eslint', 'rollup-plugin-istanbul', 'eslint-plugin-import', 'minimist', 'rollup', 'karma', 'karma-rollup-preprocessor', 'karma-coverage'}
# Total de dependências únicas: 6
# Total de devDependências únicas: 0
# Dependências sempre presentes: {'openai', 'cors', 'dotenv', 'express'}
# DevDependências sempre presentes: set()
# Total de dependências únicas: 0
# Total de devDependências únicas: 6
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'lerna', '@commitlint/config-conventional', '@commitlint/cli', 'husky'}
# Total de dependências únicas: 1
# Total de devDependências únicas: 26
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'babel'}
# Total de dependências únicas: 2
# Total de devDependências únicas: 0
# Dependências sempre presentes: {'react-navigation'}
# DevDependências sempre presentes: set()
# Total de dependências únicas: 0
# Total de devDependências únicas: 48
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 51
# Total de devDependências únicas: 47
# Dependências sempre presentes: {'compression', 'http-proxy', 'react', 'react-router', 'piping', 'file-loader', 'react-inline-css', 'url-loader', 'superagent', 'redux', 'serve-favicon', 'express', 'express-session'}
# DevDependências sempre presentes: {'json-loader', 'react-a11y', 'webpack', 'concurrently'}
# Total de dependências únicas: 4
# Total de devDependências únicas: 89
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'prettier', 'stylelint-order', 'babel-jest', 'react-test-renderer', 'eslint', 'eslint-plugin-react', 'stylelint-config-standard', 'stylelint', 'eslint-config-airbnb', 'eslint-plugin-import', 'eslint-config-prettier', 'eslint-plugin-jsx-a11y', 'identity-obj-proxy', 'jest'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 15
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 1
# Total de devDependências únicas: 2
# Dependências sempre presentes: {'invariant'}
# DevDependências sempre presentes: {'flow-bin'}
# Total de dependências únicas: 8
# Total de devDependências únicas: 20
# Dependências sempre presentes: {'lodash'}
# DevDependências sempre presentes: {'sass-loader', 'react', 'css-loader', 'react-dom', 'cache-loader', 'babel-core', 'babel-loader', 'style-loader', 'webpack'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 4
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'tailwindcss', 'daisyui'}
# Total de dependências únicas: 73
# Total de devDependências únicas: 28
# Dependências sempre presentes: {'react', 'react-dom', 'next'}
# DevDependências sempre presentes: {'tailwindcss', 'eslint', '@types/react-dom', '@types/node', 'postcss', 'eslint-config-next', 'typescript', '@types/react'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 19
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 0
# Total de devDependências únicas: 7
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'prettier', 'eslint', '@changesets/cli', 'eslint-config-evolu', 'turbo'}
# Total de dependências únicas: 11
# Total de devDependências únicas: 51
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 69
# Total de devDependências únicas: 57
# Dependências sempre presentes: {'@sentry/utils', 'lockfile', 'react', '@loadable/babel-plugin', 'react-router', 'styled-components', 'craco-antd', 'get-folder-size', 'redux-persist', 'electron-log', 'semver', 'slate', 'slate-react', 'rooks', 'react-window', 'react-router-dom', 'memoize-one', 'node-machine-id', 'uuid', 'react-redux', 'reselect', 'slate-history', '7zip-bin', 'directory-tree', 'use-debounce', 'polished', 'base64-stream', 'lodash', 'react-dom', 'react-beautiful-dnd', 'react-window-infinite-loader', 'react-content-loader', 'base64url', 'axios', 'react-virtualized-auto-sizer', 'antd', 'history', 'fast-xml-parser', '@sentry/react', 'get-stream', 'is-electron', 'react-markdown', 'react-html-parser', 'react-contextmenu', 'inter-ui', '@sentry/tracing', 'symlink-dir', 'randomstring', 'he', 'jimp', 'electron-store', 'user-agents', 'fs-extra', 'preact', 'node-7z', 'react-transition-group', 'make-dir', 'react-portal', 'typeface-roboto', 'connected-react-router', 'localforage', 'ps-tree', 'redux', '@sentry/integrations', 'react-type-animation', 'discord-rpc', 'redux-logger', 'p-map', 'react-intersection-observer'}
# DevDependências sempre presentes: {'electron-updater', 'cross-env', '@babel/plugin-syntax-dynamic-import', '@babel/register', '@babel/runtime', 'eslint-config-airbnb', 'eslint-plugin-import', 'eslint-plugin-prettier', 'eslint-plugin-react-hooks', 'webpack-merge', 'husky', 'babel-core', 'babel-loader', 'webpack', 'wait-on', 'babel-plugin-transform-react-remove-prop-types', 'dotenv', '@ant-design/icons', 'eslint-import-resolver-alias', '@fortawesome/free-regular-svg-icons', '@babel/plugin-transform-runtime', 'babel-plugin-macros', 'webpack-cli', 'eslint', 'eslint-plugin-promise', '@fortawesome/free-brands-svg-icons', '@babel/plugin-proposal-export-default-from', '@babel/plugin-proposal-class-properties', '@fortawesome/react-fontawesome', 'eslint-plugin-jsx-a11y', '@sentry/webpack-plugin', 'native-ext-loader', '@fortawesome/fontawesome-svg-core', 'babel-plugin-preval', 'prettier', 'babel-plugin-styled-components', 'babel-preset-minify', 'eslint-plugin-react', 'terser-webpack-plugin', 'eslint-config-prettier', 'eslint-formatter-pretty', '@craco/craco', 'electron', 'eslint-plugin-compat', 'babel-plugin-module-resolver', 'electron-builder', '@napi-rs/cli', '@babel/preset-env', 'rimraf', '@fortawesome/free-solid-svg-icons', 'eslint-import-resolver-webpack', '@babel/preset-react', '@babel/cli', 'webpack-bundle-analyzer', 'concurrently', 'react-scripts'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 33
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'prettier', 'typescript'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 17
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'grunt-contrib-sass', 'grunt-contrib-watch', 'grunt'}
# Total de dependências únicas: 30
# Total de devDependências únicas: 40
# Dependências sempre presentes: {'@angular/compiler', '@angular/platform-browser', '@angular/router', '@ng-bootstrap/ng-bootstrap', 'ng-jhipster', '@angular/common', 'bootstrap', 'rxjs', '@angular/forms', 'ngx-infinite-scroll', 'zone.js', '@angular/core', '@angular/platform-browser-dynamic', 'ngx-cookie'}
# DevDependências sempre presentes: {'browser-sync-webpack-plugin', '@angular/compiler-cli', '@types/node', 'rimraf', 'webpack-notifier', 'webpack-merge', 'generator-jhipster', 'typescript', 'copy-webpack-plugin', '@angular/cli', 'webpack', 'browser-sync'}
# Total de dependências únicas: 6
# Total de devDependências únicas: 25
# Dependências sempre presentes: {'react', 'react-native'}
# DevDependências sempre presentes: {'babel-jest', 'react-test-renderer', 'jest'}
# Total de dependências únicas: 2
# Total de devDependências únicas: 0
# Dependências sempre presentes: {'com.unity.xr.interaction.toolkit', 'com.unity.textmeshpro'}
# DevDependências sempre presentes: set()
# Total de dependências únicas: 13
# Total de devDependências únicas: 20
# Dependências sempre presentes: {'@fortawesome/free-regular-svg-icons', 'react', 'zustand', 'vite-plugin-css-injected-by-js', 'classnames', 'react-dom', '@noriginmedia/norigin-spatial-navigation', '@fortawesome/react-fontawesome', '@fortawesome/free-solid-svg-icons', '@fortawesome/fontawesome-svg-core', 'react-player'}
# DevDependências sempre presentes: {'eslint-plugin-react-hooks', 'jsdom', '@types/testing-library__jest-dom', 'vite', 'eslint', 'vite-plugin-dts', 'typescript', '@vitejs/plugin-react', 'vitest', '@typescript-eslint/eslint-plugin', '@typescript-eslint/parser', '@types/jest', 'eslint-plugin-react-refresh', '@types/react-dom', 'gh-pages', '@types/node', 'sass', '@testing-library/react', '@testing-library/jest-dom', '@types/react'}
# Total de dependências únicas: 2
# Total de devDependências únicas: 32
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'prettier', '@viclafouch/eslint-config-viclafouch', 'vite', 'eslint', 'typescript', '@vitejs/plugin-react'}
# Total de dependências únicas: 2
# Total de devDependências únicas: 0
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 10
# Total de devDependências únicas: 4
# Dependências sempre presentes: {'react', 'expo', 'react-native'}
# DevDependências sempre presentes: set()
# Total de dependências únicas: 2
# Total de devDependências únicas: 35
# Dependências sempre presentes: {'lerna', 'react'}
# DevDependências sempre presentes: {'prettier', '@babel/preset-react', '@babel/preset-env'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 7
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 9
# Total de devDependências únicas: 10
# Dependências sempre presentes: {'emotion-theming', 'emotion', 'react', 'react-dom', '@appbaseio/designkit', 'react-router-dom', 'react-emotion', 'react-scripts'}
# DevDependências sempre presentes: set()
# Total de dependências únicas: 0
# Total de devDependências únicas: 5
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'postcss-cli', 'autoprefixer'}
# Total de dependências únicas: 13
# Total de devDependências únicas: 1
# Dependências sempre presentes: {'commander', 'inquirer', 'figlet', 'simple-git', 'fs-extra'}
# DevDependências sempre presentes: set()
# Total de dependências únicas: 0
# Total de devDependências únicas: 12
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 27
# Total de devDependências únicas: 56
# Dependências sempre presentes: {'react', 'react-dom'}
# DevDependências sempre presentes: {'cross-env'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 41
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 0
# Total de devDependências únicas: 20
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'react', 'react-native'}
# Total de dependências únicas: 2
# Total de devDependências únicas: 63
# Dependências sempre presentes: {'dayjs'}
# DevDependências sempre presentes: {'gulp-sourcemaps', 'cross-env', 'eslint-plugin-prettier', 'eslint-plugin-import', 'miniprogram-automator', 'gulp-plumber', 'eslint', 'gulp-rename', 'gulp', 'gulp-changed', 'typescript', 'gulp-replace', 'miniprogram-api-typings', 'del', 'prettier', 'babel-jest', '@typescript-eslint/eslint-plugin', 'jest-html-reporter', 'miniprogram-simulate', '@typescript-eslint/parser', '@types/jest', 'eslint-config-prettier', 'gulp-typescript', '@babel/core', 'stylelint', 'gulp-replace-task', 'gulp-mp-npm', '@babel/preset-env', '@babel/preset-typescript', 'lint-staged', 'eslint-config-airbnb-base', 'gulp-less', 'husky', 'jest'}
# Total de dependências únicas: 4
# Total de devDependências únicas: 61
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'semver', 'stylelint-prettier', '@commitlint/cli', 'pinst', 'vite', 'is-ci', 'eslint', 'typescript', 'prettier', '@vitejs/plugin-vue', 'conventional-changelog-cli', 'execa', '@vitejs/plugin-vue-jsx', 'fs-extra', 'stylelint', 'rimraf', 'sass', 'lint-staged', '@vue/test-utils', 'husky'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 0
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 21
# Total de devDependências únicas: 14
# Dependências sempre presentes: {'history', 'react-datetime', 'moment', 'node-sass', 'react', 'nouislider', '@material-ui/icons', 'prop-types', 'classnames', 'react-dom', 'react-slick', '@material-ui/core', 'react-router-dom', 'react-ace', 'react-p5', 'react-scripts'}
# DevDependências sempre presentes: {'gulp-append-prepend', 'prettier', 'eslint-plugin-react', 'eslint-plugin-prettier', '@babel/preset-env', 'gulp', '@babel/plugin-proposal-class-properties', '@babel/preset-react', '@babel/cli', 'eslint-config-prettier'}
# Total de dependências únicas: 26
# Total de devDependências únicas: 14
# Dependências sempre presentes: {'prettier', '@tanstack/react-query-devtools', 'react', '@radix-ui/react-label', 'solidjs-dropzone', 'react-router-dom', 'eslint-config-prettier', 'tailwindcss-animate', '@radix-ui/react-toast', '@tanstack/react-query', '@hookform/resolvers', 'react-hook-form', 'zod', 'clsx', 'react-dropzone', 'react-dom', 'appwrite', '@radix-ui/react-slot', 'lucide-react', 'attr-accept', 'class-variance-authority', 'eslint-config-standard', 'eslint-plugin-tailwindcss', 'tailwind-merge', '@radix-ui/react-tabs', 'react-intersection-observer'}
# DevDependências sempre presentes: {'tailwindcss', 'vite', '@typescript-eslint/eslint-plugin', 'eslint', '@types/react-dom', '@typescript-eslint/parser', 'eslint-plugin-react-hooks', '@types/node', 'postcss', '@types/react', 'autoprefixer', 'eslint-plugin-react-refresh', 'typescript', '@vitejs/plugin-react'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 36
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 0
# Total de devDependências únicas: 3
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 15
# Total de devDependências únicas: 64
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 0
# Total de devDependências únicas: 26
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'postcss-combine-duplicated-selectors', 'svelte-check', 'eslint-plugin-svelte', 'tslib', 'svelte', '@sveltejs/adapter-static', 'prettier-plugin-tailwindcss', 'publint', 'vite', '@sveltejs/package', 'eslint', 'prettier-plugin-svelte', 'lodash', 'typescript', 'prettier', 'tailwindcss', '@typescript-eslint/eslint-plugin', '@typescript-eslint/parser', 'autoprefixer', '@types/eslint', 'eslint-config-prettier', '@types/lodash', '@sveltejs/kit', '@sveltejs/vite-plugin-svelte'}
# Total de dependências únicas: 31
# Total de devDependências únicas: 0
# Dependências sempre presentes: {'chai', 'stylelint-config-palantir', '@types/react-dom', '@types/enzyme', '@types/mocha', 'stylelint-scss', '@types/chai', '@types/react', 'sinon'}
# DevDependências sempre presentes: set()
# Total de dependências únicas: 88
# Total de devDependências únicas: 21
# Dependências sempre presentes: {'react', 'react-native', 'prop-types', 'expo', 'deepmerge', 'mobx-react', '@ant-design/react-native', 'react-navigation', 'mobx', 'react-native-modal-popover'}
# DevDependências sempre presentes: {'eslint-plugin-react', 'eslint'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 29
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'eslint-plugin-flowtype', 'eslint-plugin-react', '@typescript-eslint/eslint-plugin', 'eslint-config-react-app', 'eslint', '@typescript-eslint/parser', 'eslint-plugin-react-hooks', 'eslint-plugin-import', 'eslint-plugin-header', 'eslint-plugin-jsx-a11y', 'license-checker', 'lint-staged', 'git-conventional-commits', 'husky'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 0
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 14
# Total de devDependências únicas: 58
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'@storybook/addons', '@storybook/addon-links', '@storybook/react', '@storybook/addon-actions'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 7
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 3
# Total de devDependências únicas: 0
# Dependências sempre presentes: {'prop-types'}
# DevDependências sempre presentes: set()
# Total de dependências únicas: 0
# Total de devDependências únicas: 0
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 0
# Total de devDependências únicas: 41
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'prettier', 'eslint-plugin-svelte3', '@typescript-eslint/eslint-plugin', 'eslint', '@typescript-eslint/parser', 'svelte-check', 'prettier-plugin-svelte', 'svelte-preprocess', 'eslint-config-prettier', '@sveltejs/kit', '@sveltejs/adapter-auto', 'tslib', 'svelte', 'typescript'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 27
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'react', '@types/styled-components', 'semver', '@mdx-js/react', '@types/enzyme-adapter-react-16', 'pepjs', 'react-dom', 'typescript', 'babel-plugin-styled-components', '@types/jest', 'typescript-styled-plugin', '@babel/core', 'jest-styled-components', '@types/react-dom', '@babel/preset-env', '@types/enzyme', '@babel/preset-typescript', '@babel/preset-react', '@babel/cli', '@types/react', 'jest'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 30
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'prettier', 'eslint-config-satya164', 'react', 'react-native', '@expo/vector-icons', 'react-test-renderer', 'eslint', 'babel-jest', 'react-dom', 'eslint-plugin-react-native-globals', 'husky', 'jest'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 14
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'prettier', 'react', 'react-native', 'eslint', 'typescript', '@types/react'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 0
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 27
# Total de devDependências únicas: 4
# Dependências sempre presentes: {'html-loader', 'eslint-plugin-prettier', 'css-loader', 'webpack-merge', 'css-minimizer-webpack-plugin', 'mini-css-extract-plugin', 'babel-loader', 'file-loader', 'eslint', 'copy-webpack-plugin', 'glob', 'html-webpack-plugin', 'prettier', 'reachable-url', 'purgecss-webpack-plugin', 'glob-all', 'eslint-config-prettier', 'style-loader', '@babel/core', 'webpack-dev-server', 'node-sass', 'clean-webpack-plugin', 'eslint-webpack-plugin', '@babel/preset-env', 'sass', 'postcss', 'sass-loader'}
# DevDependências sempre presentes: {'webpack', 'ejs', 'webpack-cli', 'template-ejs-loader'}
# Total de dependências únicas: 1
# Total de devDependências únicas: 25
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'babel-jest', 'react-test-renderer', 'jest'}
# Total de dependências únicas: 6
# Total de devDependências únicas: 12
# Dependências sempre presentes: {'three-globe', 'three', 'three-render-objects', 'kapsule', 'accessor-fn'}
# DevDependências sempre presentes: {'@babel/preset-env', '@babel/core', 'rollup'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 15
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'prettier', 'eslint-config-satya164', 'eslint', 'commitlint', 'typescript', '@commitlint/config-conventional', 'jest'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 19
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 20
# Total de devDependências únicas: 13
# Dependências sempre presentes: {'bootstrap', 'jquery', 'woofmark', 'bootstrap-datepicker'}
# DevDependências sempre presentes: {'grunt', 'grunt-contrib-concat', 'grunt-contrib-watch', 'matchdep'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 0
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 0
# Total de devDependências únicas: 35
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 18
# Total de devDependências únicas: 60
# Dependências sempre presentes: {'ant-design-vue', 'vue-router', 'axios', 'vue'}
# DevDependências sempre presentes: {'vite'}
# Total de dependências únicas: 67
# Total de devDependências únicas: 43
# Dependências sempre presentes: {'vue', '@vueuse/core', 'naive-ui', 'pinia', 'vue-router'}
# DevDependências sempre presentes: {'prettier', '@vitejs/plugin-vue', 'vitest', 'vite', '@types/jsdom', 'eslint', '@vitejs/plugin-vue-jsx', 'less', '@types/node', 'jsdom', '@rushstack/eslint-patch', '@vue/test-utils', 'typescript', '@vue/tsconfig'}
# Total de dependências únicas: 6
# Total de devDependências únicas: 35
# Dependências sempre presentes: {'react', 'react-native', 'redux-thunk', 'redux', 'react-native-navigation', 'react-redux'}
# DevDependências sempre presentes: {'babel-jest', 'react-test-renderer', 'eslint-plugin-react', 'eslint', 'eslint-watch', 'eslint-config-airbnb', 'eslint-plugin-import', 'jest', 'eslint-plugin-jsx-a11y', 'babel-eslint', 'babel-core', 'babel-preset-airbnb', 'babel-preset-react-native', 'metro-react-native-babel-preset', 'eslint-plugin-jest', 'regenerator-runtime'}
# Total de dependências únicas: 99
# Total de devDependências únicas: 61
# Dependências sempre presentes: {'ws', 'config', 'morgan', 'multer', 'express-validator', 'winston', 'express'}
# DevDependências sempre presentes: {'mocha', 'chai', 'supertest'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 3
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 64
# Total de devDependências únicas: 9
# Dependências sempre presentes: {'react', '@testing-library/cypress', 'axe-core', 'rifm', '@storybook/addon-links', 'vite-tsconfig-paths', 'ag-grid-enterprise', '@testing-library/dom', 'dom-accessibility-api', '@types/tinycolor2', '@cypress/code-coverage', 'vite', 'react-dom', '@storybook/addon-docs', '@storybook/react', 'typescript', '@vitejs/plugin-react', 'prettier', 'ag-grid-community', 'cypress-real-events', '@storybook/addon-actions', '@storybook/addon-essentials', '@types/react-color', '@types/no-scroll', 'cypress', 'vite-plugin-istanbul', '@types/react-dom', 'deepmerge', 'ag-grid-react', '@types/node', '@changesets/cli', 'cypress-axe', '@types/react'}
# DevDependências sempre presentes: set()
# Total de dependências únicas: 31
# Total de devDependências únicas: 10
# Dependências sempre presentes: {'react', 'react-native', 'react-native-screens', 'react-native-document-picker', '@react-navigation/drawer', '@react-native-community/netinfo', 'react-native-gesture-handler', 'stream-chat-react-native', 'stream-chat', '@stream-io/react-native-simple-markdown', '@react-navigation/native', 'react-native-image-picker', '@react-native-community/masked-view', 'react-native-safe-area-context'}
# DevDependências sempre presentes: {'babel-jest', 'react-test-renderer', 'eslint', 'reactotron-react-native', '@react-native-community/eslint-config', '@babel/runtime', 'metro-react-native-babel-preset', '@babel/core', 'jest'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 12
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'eslint-config-mdcs', '@rollup/plugin-node-resolve', 'rollup-plugin-root-import', 'uglify-es', 'eslint', '@rollup/plugin-alias', 'rollup', 'rollup-plugin-visualizer', '@rollup/plugin-sucrase', '@rollup/plugin-replace', '@rollup/plugin-commonjs', 'rollup-plugin-string'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 70
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 13
# Total de devDependências únicas: 25
# Dependências sempre presentes: {'@angular/platform-browser', '@ionic/angular', '@angular/router', '@ionic-native/core', '@angular/common', 'rxjs', '@angular/forms', 'core-js', '@ionic-native/splash-screen', '@ionic-native/status-bar', '@angular/core', '@angular/platform-browser-dynamic', 'zone.js'}
# DevDependências sempre presentes: {'@angular/compiler', '@types/jasmine', 'karma-chrome-launcher', '@angular/language-service', '@types/jasminewd2', '@angular-devkit/core', '@angular-devkit/schematics', 'ts-node', 'karma', 'jasmine-spec-reporter', 'jasmine-core', 'tslint', 'typescript', 'protractor', 'karma-coverage-istanbul-reporter', 'codelyzer', 'karma-jasmine', '@angular-devkit/build-angular', 'karma-jasmine-html-reporter', '@angular/compiler-cli', '@types/node', '@angular-devkit/architect', '@angular/cli'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 10
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'prettier', 'eslint-plugin-react', 'eslint', 'eslint-config-airbnb', 'eslint-plugin-import', 'eslint-plugin-prettier', 'eslint-plugin-jsx-a11y', 'lint-staged', 'eslint-config-prettier', 'pre-commit'}
# Total de dependências únicas: 12
# Total de devDependências únicas: 100
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 3
# Total de devDependências únicas: 17
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 0
# Total de devDependências únicas: 4
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 23
# Total de devDependências únicas: 9
# Dependências sempre presentes: {'react', 'react-dom', 'next'}
# DevDependências sempre presentes: {'tailwindcss', 'eslint', '@types/react-dom', '@types/node', 'postcss', 'autoprefixer', 'eslint-config-next', 'typescript', '@types/react'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 6
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'lerna'}
# Total de dependências únicas: 3
# Total de devDependências únicas: 56
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 29
# Total de devDependências únicas: 17
# ...
# Dependências sempre presentes: {'babel-polyfill'}
# DevDependências sempre presentes: set()
# Total de dependências únicas: 16
# Total de devDependências únicas: 108
# Dependências sempre presentes: {'@babel/runtime'}
# DevDependências sempre presentes: {'react', 'eslint-plugin-react-hooks', '@testing-library/dom', '@rollup/plugin-replace', 'dts-bundle-generator', 'express', 'extract-mdx-metadata', 'typescript', 'eslint-plugin-markdown', '@types/jest', 'eslint-config-prettier', 'jest-environment-jsdom', 'node-sass', 'rehype-join-line', 'npm-run-all', '@types/node', '@babel/preset-typescript', 'tslint-to-eslint-config', '@mdx-js/loader', 'babel-plugin-tsconfig-paths-module-resolver', 'cross-env', '@types/mocha', 'eslint', 'typescript-transform-paths', 'react-dom', 'lodash', '@babel/plugin-transform-class-properties', '@rollup/plugin-terser', 'tslint', '@vercel/analytics', '@typescript-eslint/eslint-plugin', 'eslint-config-next', '@types/react-color', 'fs-extra', '@babel/core', '@types/lodash', 'eslint-plugin-mdx', 'ts-transformer-properties-rename', '@types/mdx', 'reflect-metadata', '@babel/preset-env', '@next/bundle-analyzer', 'sass', '@next/mdx', '@rollup/plugin-babel', '@babel/cli', 'next', 'prism-react-renderer', 'remark-mdx', 'eslint-plugin-prefer-arrow', 'ts-transformer-strip-const-enums', '@types/glob', 'tslib', 'eslint-config-ts-lambdas', 'prettier', 'rollup-plugin-local-resolve', '@babel/plugin-transform-block-scoping', '@next/eslint-plugin-next', '@svgr/cli', '@use-gesture/react', 'react-live', '@babel/preset-react', '@testing-library/jest-dom', 'husky', 'react-color', 'eslint-plugin-import', 'mocha', 'eslint-plugin-unicorn', 'pngjs', '@rollup/plugin-commonjs', '@babel/plugin-transform-runtime', 'ts-node', 'rollup', '@mapbox/rehype-prism', 'ts-jest', 'eslint-plugin-tsdoc', 'ttsc', '@rollup/plugin-node-resolve', 'babel-jest', '@styled-jsx/plugin-sass', 'eslint-plugin-react', '@types/pngjs', '@typescript-eslint/parser', 'remark-gfm', 'babel-plugin-transform-rename-import', '@types/react-dom', '@testing-library/user-event', '@types/react', 'jest'}
# Total de dependências únicas: 2
# Total de devDependências únicas: 0
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 0
# Total de devDependências únicas: 10
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 15
# Total de devDependências únicas: 34
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'fs-extra', 'async'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 0
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 0
# Total de devDependências únicas: 36
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'babel-cli', 'react', 'lodash.noop', 'cross-env', 'expect', 'mocha', 'babel-core', 'babel-loader', 'webpack', 'react-tap-event-plugin', 'eslint', 'react-dom', 'eslint-plugin-react', 'babel-preset-react', 'babel-eslint', 'material-ui', 'mocha-lcov-reporter', 'codecov.io', 'expect-jsx', 'babel-preset-stage-2', 'isparta', 'rimraf', 'babel-register'}
# Total de dependências únicas: 16
# Total de devDependências únicas: 22
# Dependências sempre presentes: {'vuex-router-sync', 'copy-text-to-clipboard', 'vue', 'consola', 'vuex', 'element-ui', 'lodash', 'nprogress', 'vue-router', '@vue/composition-api', 'core-js', 'vee-validate', '@fext/vue-use', 'json2csv', 'axios'}
# DevDependências sempre presentes: {'vue-template-compiler', '@vue/cli-plugin-router', 'cross-env', 'eslint-plugin-prettier', '@commitlint/cli', '@vue/eslint-config-standard', 'eslint-plugin-vue', 'eslint', '@vue/cli-plugin-vuex', 'prettier', '@vue/cli-plugin-babel', 'babel-eslint', '@vue/cli-plugin-eslint', '@vue/cli-service', 'eslint-config-prettier', '@commitlint/config-conventional', '@vue/cli-plugin-unit-jest', 'sass', 'lint-staged', '@vue/test-utils', 'sass-loader', 'husky'}
# Total de dependências únicas: 53
# Total de devDependências únicas: 61
# Dependências sempre presentes: {'vue', 'morgan', 'mqtt', 'vuetify', 'cookie-parser', 'cors', 'vue-router', 'express', 'jsonfile', 'axios'}
# DevDependências sempre presentes: {'vue-template-compiler', 'semver', 'rimraf'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 1
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 8
# Total de devDependências únicas: 61
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'html-loader', 'vue-hot-reload-api', 'less', 'css-loader', 'vue-router', 'babel-core', 'babel-loader', 'webpack', 'less-loader', 'file-loader', 'eslint', 'gulp-rename', 'gulp', 'vue-loader', 'babel-runtime', 'vue-html-loader', 'style-loader', 'vue-style-loader', 'url-loader', 'autoprefixer-loader', 'babel-plugin-transform-runtime', 'gulp-less'}
# Total de dependências únicas: 10
# Total de devDependências únicas: 0
# Dependências sempre presentes: {'mongodb', 'body-parser', 'express'}
# DevDependências sempre presentes: set()
# Total de dependências únicas: 37
# Total de devDependências únicas: 24
# Dependências sempre presentes: {'react', 'react-dom'}
# DevDependências sempre presentes: set()
# Total de dependências únicas: 26
# Total de devDependências únicas: 37
# Dependências sempre presentes: {'shortid', 'vue', 'echarts', 'html2canvas', 'accounting', 'element-plus', 'monaco-editor', 'vue-router', 'dayjs', 'axios'}
# DevDependências sempre presentes: {'cross-env', 'eslint-plugin-import', '@vue/compiler-sfc', '@commitlint/cli', 'eslint-plugin-vue', 'eslint', 'stylelint-config-prettier', 'typescript', '@typescript-eslint/eslint-plugin', '@typescript-eslint/parser', '@vue/component-compiler-utils', '@commitlint/config-conventional', '@babel/core', 'stylelint', 'stylelint-config-standard', '@babel/preset-env', 'rimraf', 'sass', '@babel/preset-typescript', 'lint-staged', 'husky'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 14
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'flow-bin', 'eslint', 'babel-eslint', 'sane'}
# Total de dependências únicas: 75
# Total de devDependências únicas: 39
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'prettier', 'vite', 'vitest', '@sveltejs/package', '@typescript-eslint/eslint-plugin', 'eslint', '@typescript-eslint/parser', 'svelte-check', 'prettier-plugin-svelte', 'typescript', '@sveltejs/kit', '@sveltejs/adapter-auto', 'eslint-plugin-svelte', 'tslib', 'svelte', 'eslint-config-prettier', 'publint'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 12
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'hasha', 'globby', 'defu', 'typescript', 'js-yaml'}
# Total de dependências únicas: 6
# Total de devDependências únicas: 7
# Dependências sempre presentes: {'react', 'react-native', 'react-vr', 'three', 'ovrui', 'react-vr-web'}
# DevDependências sempre presentes: {'babel-jest', 'react-test-renderer', 'xopen', 'react-devtools', 'babel-preset-react-native', 'jest'}
# Total de dependências únicas: 2
# Total de devDependências únicas: 48
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'prettier', '@testing-library/jest-dom', '@types/jest', 'jest-watch-typeahead', 'pretty-quick', 'ts-jest', 'typescript', '@types/react', 'husky', 'jest'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 44
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 43
# Total de devDependências únicas: 0
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 66
# Total de devDependências únicas: 0
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 18
# Total de devDependências únicas: 24
# Dependências sempre presentes: {'framer-motion', 'react', '@emotion/styled', '@chakra-ui/react', 'react-dom', 'next', '@emotion/react'}
# DevDependências sempre presentes: {'prettier', 'typescript', '@types/node', '@testing-library/react', '@testing-library/jest-dom', '@types/react', 'husky', 'jest'}
# Total de dependências únicas: 16
# Total de devDependências únicas: 51
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'dedent', '@types/react-dom', 'rimraf', 'lerna', 'lint-staged', 'typescript', '@types/react', '@babel/core', 'husky'}
# Total de dependências únicas: 75
# Total de devDependências únicas: 36
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'@typescript-eslint/eslint-plugin', 'eslint', '@typescript-eslint/parser', '@types/react', 'typescript', '@types/react-native', '@babel/core'}
# Total de dependências únicas: 0
# Total de devDependências únicas: 45
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'sort-package-json', 'eslint-plugin-prettier', 'eslint-plugin-import', 'eslint-plugin-solid', 'solid-testing-library', '@commitlint/cli', 'solid-js', '@commitlint/cz-commitlint', 'vite', 'eslint', 'eslint-plugin-jsx-a11y', 'typescript', 'turbo', 'prettier', 'eslint-config-prettier', '@commitlint/config-conventional', 'vite-plugin-solid', 'commitizen', '@changesets/cli', 'lint-staged', 'eslint-import-resolver-typescript', 'eslint-plugin-simple-import-sort', 'husky'}
# Total de dependências únicas: 57
# Total de devDependências únicas: 36
# Dependências sempre presentes: {'source-map-support'}
# DevDependências sempre presentes: {'eslint-plugin-vue', 'eslint', 'eslint-plugin-promise', 'eslint-plugin-import', 'eslint-config-standard', 'eslint-plugin-node'}
# Total de dependências únicas: 12
# Total de devDependências únicas: 87
# Dependências sempre presentes: {'react', 'lodash.throttle', '@arco-design/transformable', 'es6-promise', 'react-dom', 'react-router-dom', 'lodash.debounce', 'axios', 'react-transition-group'}
# DevDependências sempre presentes: {'html-loader', 'gulp-babel', 'cross-env', 'eslint-plugin-react-hooks', 'eslint-config-airbnb', 'css-loader', 'eslint-plugin-prettier', 'less', 'webpack-merge', 'eslint-plugin-babel', 'eslint-plugin-import', '@types/lodash.throttle', 'tslib', '@rollup/plugin-typescript', 'mini-css-extract-plugin', '@rollup/plugin-replace', 'babel-loader', '@rollup/plugin-commonjs', 'webpack', 'less-loader', '@commitlint/cli', 'vconsole-webpack-plugin', '@babel/plugin-transform-runtime', '@types/react-router-dom', 'postcss-url', '@types/react-transition-group', 'webpack-cli', '@types/marked', 'eslint', 'gulp', '@babel/plugin-proposal-class-properties', 'eslint-plugin-jsx-a11y', '@rollup/plugin-alias', 'rollup', 'schema-utils', 'typescript', '@babel/eslint-plugin', 'gulp-replace', 'html-webpack-plugin', '@types/lodash.debounce', 'prettier', 'less-plugin-npm-import', '@rollup/plugin-node-resolve', 'babel-jest', '@typescript-eslint/eslint-plugin', 'eslint-plugin-react', '@typescript-eslint/parser', 'hasha', 'lerna', 'autoprefixer', 'eslint-config-prettier', '@commitlint/config-conventional', '@babel/core', 'gulp-typescript', 'webpack-dev-server', '@types/react-dom', 'postcss-loader', 'marked', '@babel/preset-env', 'rollup-plugin-postcss', '@babel/preset-typescript', 'postcss', '@rollup/plugin-babel', 'ts-loader', '@babel/preset-react', 'lint-staged', '@types/react', 'gulp-postcss', 'gulp-less', 'husky', 'jest'}
# Total de dependências únicas: 20
# Total de devDependências únicas: 5
# Dependências sempre presentes: {'react-notifications', 'react', 'chart.js', '@reduxjs/toolkit', 'react-dom', '@testing-library/user-event', 'react-chartjs-2', '@testing-library/react', 'theme-change', '@heroicons/react', 'web-vitals', 'react-router-dom', '@testing-library/jest-dom', 'react-redux', 'axios', 'react-scripts'}
# DevDependências sempre presentes: {'tailwindcss', 'postcss', '@tailwindcss/typography', 'autoprefixer'}
# Total de dependências únicas: 2
# Total de devDependências únicas: 16
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 9
# Total de devDependências únicas: 1
# Dependências sempre presentes: {'react', 'react-dom', '@testing-library/user-event', 'react-frame-component', '@testing-library/react', 'html2jade', 'react-syntax-highlighter', '@testing-library/jest-dom', 'react-scripts'}
# DevDependências sempre presentes: {'gh-pages'}
# Total de dependências únicas: 4
# Total de devDependências únicas: 11
# Dependências sempre presentes: {'prop-types', 'react'}
# DevDependências sempre presentes: {'conventional-changelog-cli', 'postcss-cli', 'autoprefixer', 'rimraf'}
# Total de dependências únicas: 6
# Total de devDependências únicas: 8
# Dependências sempre presentes: {'vue'}
# DevDependências sempre presentes: set()
# Total de dependências únicas: 0
# Total de devDependências únicas: 18
# Dependências sempre presentes: set()
# DevDependências sempre presentes: set()
# Total de dependências únicas: 32
# Total de devDependências únicas: 30
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'prettier'}
# Total de dependências únicas: 3
# Total de devDependências únicas: 22
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'grunt-stylelint', 'pixrem', 'stylelint-config-wikimedia', 'postcss-import', 'postcss', 'grunt-contrib-watch', 'postcss-cssnext', 'grunt', 'grunt-exec', 'postcss-custom-properties'}
# Total de dependências únicas: 3
# Total de devDependências únicas: 21
# Dependências sempre presentes: set()
# DevDependências sempre presentes: {'prettier', 'react', 'react-native', 'auto-changelog', 'eslint', '@react-native-community/eslint-config', 'eslint-plugin-prettier', 'eslint-config-prettier', '@types/react-native', 'release-it', '@release-it/conventional-changelog', 'typescript', '@types/react', '@commitlint/config-conventional', '@commitlint/cli', 'husky'}
# Total de dependências únicas: 13
# Total de devDependências únicas: 45
# Dependências sempre presentes: {'msgpack5', 'vuex-electron', 'vue', 'vuex', 'element-ui', 'bluebird', '@fortawesome/free-solid-svg-icons', 'vue-progressbar', 'vue-router', '@fortawesome/vue-fontawesome', '@fortawesome/fontawesome-svg-core', 'vue-electron', 'axios'}
# DevDependências sempre presentes: {'vue-template-compiler', 'ajv', 'cross-env', 'css-loader', 'eslint-plugin-import', 'webpack-merge', 'babel-core', 'babel-loader', 'mini-css-extract-plugin', 'node-loader', 'webpack', 'eslint-plugin-html', 'webpack-hot-middleware', 'file-loader', 'webpack-cli', 'chalk', 'electron-debug', 'eslint', 'eslint-plugin-promise', 'cfonts', 'electron-devtools-installer', 'eslint-config-standard', 'copy-webpack-plugin', 'vue-loader', 'html-webpack-plugin', 'del', 'babel-preset-env', 'vue-html-loader', 'babel-eslint', 'style-loader', 'vue-style-loader', 'babel-preset-stage-0', 'eslint-loader', 'electron', 'webpack-dev-server', 'url-loader', 'electron-builder', 'eslint-friendly-formatter', 'eslint-plugin-standard', 'eslint-plugin-node', 'devtron', 'babel-plugin-transform-runtime', 'babel-register'}
# Total de dependências únicas: 60
# Total de devDependências únicas: 54
# Dependências sempre presentes: {'history', 'moment', 'react', 'react-google-recaptcha', 'react-router', 'react-date-picker', 'js-yaml', 'react-dom', 'redux', 'moment-timezone', 'bitcoincashjs', 'react-router-dom', 'redux-saga', 'react-redux', 'axios'}
# DevDependências sempre presentes: {'enzyme-adapter-react-16', 'classnames', 'postcss-autoreset', 'postcss-import', '@types/jquery', 'axios-mock-adapter', '@types/react-router', '@types/classnames', '@types/enzyme-adapter-react-16', 'cssnano', 'ramda', '@types/react-test-renderer', '@types/react-router-dom', 'file-loader', 'react-test-renderer', 'chalk', '@types/webpack-env', 'ts-node', '@openware/coding-standards', 'enzyme-to-json', 'ts-jest', 'typescript', '@types/axios', 'babel-jest', '@types/jest', '@types/react-redux', 'autoprefixer', 'react-hot-loader', '@types/history', 'redux-mock-store', 'enzyme', 'postcss-nested', 'npm-run-all', '@types/react-dom', '@types/node', '@types/enzyme', 'rimraf', '@types/react-hot-loader', '@types/react', 'husky', 'jest'}

# %%
# Perform initial analysis to answer each research question.
import pandas as pd
# 1. Identificar as dependências mais comuns entre os projetos UI.
# Contar a ocorrência de cada dependência presente em "always_present_dependencies"
from collections import Counter

# Load the CSV file to examine its structure and content
file_path = '../Database/Questao3/final_analysis.csv'
data = pd.read_csv(file_path)

# Display the first few rows and column names to understand the structure of the dataset
data.head(), data.columns

# Flattening the dependencies list and counting occurrences
all_dependencies = data['always_present_dependencies'].dropna().str.split(',').sum()
dependency_counts = Counter([dep.strip() for dep in all_dependencies])

# Obter as dependências mais comuns
most_common_dependencies = dependency_counts.most_common(20)

# Flattening the dependencies list and counting occurrences
all_devdependencies = data['always_present_dev_dependencies'].dropna().str.split(',').sum()
devdependency_counts = Counter([dep.strip() for dep in all_devdependencies])

# Obter as dependências mais comuns
most_common_devdependencies = devdependency_counts.most_common(20)

# 2. Analisar a relação entre número de dependências e características (total dependencies as proxy for project size)
# Estatísticas descritivas para o total de dependências e de dependências de desenvolvimento
total_dependencies_stats = data[['total_unique_dependencies', 'total_unique_dev_dependencies']].describe()

# 3. Verificar a consistência de dependências (se houve mudanças significativas) ao longo dos commits
# Contagem de valores não nulos em 'always_present_dependencies' e 'always_present_dev_dependencies'
consistency_counts = data[['always_present_dependencies', 'always_present_dev_dependencies']].notnull().sum()

most_common_dependencies, most_common_devdependencies ,total_dependencies_stats, consistency_counts
# Out:
# ([('react', 120),
#   ('react-dom', 88),
#   ('react-native', 37),
#   ('react-scripts', 29),
#   ('vue', 29),
#   ('react-router-dom', 22),
#   ('next', 22),
#   ('axios', 21),
#   ('lodash', 20),
#   ('react-redux', 17),
#   ('redux', 16),
#   ('@testing-library/react', 16),
#   ('@testing-library/jest-dom', 16),
#   ('prop-types', 15),
#   ('vue-router', 15),
#   ('@testing-library/user-event', 15),
#   ('express', 13),
#   ('bootstrap', 13),
#   ('web-vitals', 12),
#   ('react-navigation', 11)],
#  [('eslint', 156),
#   ('typescript', 135),
#   ('prettier', 94),
#   ('jest', 67),
#   ('webpack', 63),
#   ('@types/react', 58),
#   ('husky', 58),
#   ('babel-loader', 52),
#   ('@types/node', 52),
#   ('eslint-plugin-import', 50),
#   ('eslint-plugin-react', 50),
#   ('autoprefixer', 46),
#   ('react', 44),
#   ('react-test-renderer', 44),
#   ('css-loader', 43),
#   ('@babel/core', 43),
#   ('babel-eslint', 42),
#   ('eslint-config-prettier', 41),
#   ('babel-core', 40),
#   ('rimraf', 39)],
#         total_unique_dependencies  total_unique_dev_dependencies
#  count                 695.000000                     695.000000
#  mean                    9.671942                      24.661871
#  std                    16.784754                      27.840000
#  min                     0.000000                       0.000000
#  25%                     0.000000                       6.000000
#  50%                     2.000000                      18.000000
#  75%                    12.000000                      34.000000
#  max                   124.000000                     320.000000,
#  always_present_dependencies        251
#  always_present_dev_dependencies    408
#  dtype: int64)
