# %% [markdown]
# # Busca pelos arquivos de configurações dos repositórios
#
# Na tentativa de responder a primeira questão de pesquisa, primeiro é feito a busca do arquivos de configurações do dataset gerado, como por exemplo o arquivo package.json e etc
#
# ## Importação de Bibliotecas
#
# - **pandas (`pd`)**: Para manipulação de dados em formato tabular.
# - **matplotlib.pyplot (`plt`)**: Para visualização de gráficos.
# - **os**: Para interagir com o sistema operacional, como criação de diretórios.
#
# ## Funcionalidades
#
# 1. **Autenticação no GitHub**: O script começa com a autenticação na API do GitHub usando um token de acesso pessoal.
#
# 2. **Carregamento de Dados**: Carrega um arquivo CSV que contém uma lista de repositórios do GitHub.
#
# 3. **Leitura de Arquivos**: Define uma função `ler_arquivo` que tenta ler o conteúdo de arquivos específicos dentro de cada repositório. Se a leitura falhar, retorna `None`.
#
# 4. **Iteração sobre Repositórios**: Para cada repositório listado no CSV, o script:
#    - Tenta acessar o repositório no GitHub.
#    - Lê o conteúdo de uma lista predefinida de arquivos (ex: `package.json`, `vite.config.js`, etc.).
#    - Armazena os resultados em uma lista.
#
# 5. **Salvamento dos Resultados**: Cria um DataFrame a partir dos resultados coletados e salva em um novo arquivo CSV, garantindo que o diretório de saída exista.
#
#
# ## Observações**
# Esse script tem um tempo médio de 2 a 3 horas de execução.

# %%
import pandas as pd
from github import Github
import os

# Substitua 'seu_token_de_acesso' pelo seu token de acesso pessoal
token = "SEU-TOKEN"
g = Github(token)

# Carrega o arquivo CSV
# Substitua pelo caminho do seu arquivo CSV
csv_file_path = "../Database/Resultados-Busca/repositories.csv"
data = pd.read_csv(csv_file_path)

# Função para ler o conteúdo de um arquivo específico


def ler_arquivo(repo, caminho_arquivo):
    try:
        arquivo = repo.get_contents(caminho_arquivo)
        return arquivo.decoded_content.decode('utf-8')
    except Exception as e:
        # Retorna None se ocorrer um erro
        return None


# Lista para armazenar os dados
resultados = []

# Itera sobre cada repositório no DataFrame
for index, row in data.iterrows():
    repo_name = row['name']  # Nome do repositório
    print(f"Lendo repositório: {repo_name}")

    try:
        repo = g.get_repo(repo_name)
        arquivos_para_ler = [
            'package.json',
            'package-lock.json',
            'composer.json',
            'composer.lock',
            'vite.config.js',
            'angular.json',
            'tsconfig.json',
            'babel.config.js',
            'gatsby-config.js',
            'postcss.config.js',
            'vue.config.js'
        ]

        # Lê e armazena o conteúdo de cada arquivo
        for arquivo in arquivos_para_ler:
            conteudo = ler_arquivo(repo, arquivo)
            if conteudo is not None:  # Apenas adiciona se não houver erro
                resultados.append({
                    'repository': repo_name,
                    'file': arquivo,
                    'content': conteudo
                })

    except Exception as e:
        print(f"Erro ao acessar o repositório {repo_name}: {e}")

# Cria um DataFrame com os resultados
df_resultados = pd.DataFrame(resultados)

# Cria a pasta ../Database/pesquisa se não existir
output_dir = '../Database/Questao1'
os.makedirs(output_dir, exist_ok=True)

# Salva os resultados em um arquivo CSV
output_file_path = os.path.join(output_dir, 'resultados.csv')
df_resultados.to_csv(output_file_path, index=False)

print(f"Resultados salvos em: {output_file_path}")
# Out:
# Lendo repositório: XiaoMi/hiui
# Lendo repositório: ant-design/ant-design
# Lendo repositório: Tencent/weui
# Lendo repositório: tailwindlabs/headlessui
# Lendo repositório: vueComponent/ant-design-vue
# Lendo repositório: material-components/material-components-web
# Lendo repositório: radix-ui/primitives
# Lendo repositório: Tencent/weui-wxss
# Lendo repositório: shoelace-style/shoelace
# Lendo repositório: epicmaxco/vuestic-admin
# Lendo repositório: akveo/react-native-ui-kitten
# Lendo repositório: magicuidesign/magicui
# Lendo repositório: NG-ZORRO/ng-zorro-antd
# Lendo repositório: DouyinFE/semi-design
# Lendo repositório: museui/muse-ui
# Lendo repositório: akveo/nebular
# Lendo repositório: Lona/Lona
# Lendo repositório: creativetimofficial/material-kit
# Lendo repositório: ant-design-blazor/ant-design-blazor
# Lendo repositório: yeun/open-color
# Lendo repositório: arco-design/arco-design
# Lendo repositório: pinterest/gestalt
# Lendo repositório: zdhxiong/mdui
# Lendo repositório: JosephusPaye/Keen-UI
# Lendo repositório: chakra-ui/zag
# Lendo repositório: epicmaxco/vuestic-ui
# Lendo repositório: didi/mand-mobile
# Lendo repositório: unovue/radix-vue
# Lendo repositório: invertase/react-native-material-design
# Lendo repositório: arco-design/arco-design-vue
# Lendo repositório: alibaba/ChatUI
# Lendo repositório: lobehub/sd-webui-lobe-theme
# Lendo repositório: radix-ui/design-system
# Lendo repositório: arielsalminen/vue-design-system
# Lendo repositório: FE-Driver/vue-beauty
# Lendo repositório: DevCloudFE/ng-devui
# Lendo repositório: creativetimofficial/now-ui-kit
# Lendo repositório: franken-ui/ui
# Lendo repositório: cschroeter/park-ui
# Lendo repositório: adrianhajdin/brainwave
# Lendo repositório: mdbootstrap/mdb-react-ui-kit
# Lendo repositório: inkline/inkline
# Lendo repositório: lmsqueezy/wedges
# Lendo repositório: StaticMania/keep-react
# Lendo repositório: Trendyol/baklava
# Lendo repositório: kobaltedev/kobalte
# Lendo repositório: vechai/vechaiui
# Lendo repositório: mdbootstrap/mdb-angular-ui-kit
# Lendo repositório: DevCloudFE/vue-devui
# Lendo repositório: mdbootstrap/mdb-vue-ui-kit
# Lendo repositório: gorhom/react-native-paper-onboarding
# Lendo repositório: atom-material/atom-material-ui
# Lendo repositório: NG-ZORRO/ng-zorro-antd-mobile
# Lendo repositório: TheComputerM/svelte-materialify
# Lendo repositório: AKAspanion/ui-neumorphism
# Lendo repositório: Ramotion/react-native-circle-menu
# Lendo repositório: sersavan/shadcn-multi-select-component
# Lendo repositório: system-ui/theme-specification
# Lendo repositório: balmjs/balm-ui
# Lendo repositório: bareynol/mui-theme-creator
# Lendo repositório: arco-design/arco-design-mobile
# Lendo repositório: skiff-org/skiff-ui
# Lendo repositório: jeanverster/chakra-ui-steps
# Lendo repositório: creativetimofficial/vue-material-kit
# Lendo repositório: mdbootstrap/perfect-scrollbar
# Lendo repositório: c8r/lab
# Lendo repositório: outpostHQ/numl
# Lendo repositório: TeamWertarbyte/mdi-material-ui
# Lendo repositório: NewOldMax/react-material-ui-form-validator
# Lendo repositório: jetstyle/Apple-Vision-Pro-UI-Kit
# Lendo repositório: lirongtong/miitvip-vue-admin-manager
# Lendo repositório: Workday/canvas-kit
# Lendo repositório: boltdesignsystem/bolt
# Lendo repositório: angular-material-extensions/password-strength
# Lendo repositório: Decathlon/vitamin-web
# Lendo repositório: maxnowack/signaldb
# Lendo repositório: NSFI/ppfish-components
# Lendo repositório: zzuu666/antue
# Lendo repositório: selfishprimate/sketchize
# Lendo repositório: anastasiaprh/product-design-roadmap
# Lendo repositório: damien-schneider/cuicui
# Lendo repositório: yamankatby/react-native-material
# Lendo repositório: GeekyAnts/react-native-aria
# Lendo repositório: BootstrapDash/Stellar
# Lendo repositório: momentum-design/momentum-ui
# Lendo repositório: ayroui/bootstrap-ui-components
# Lendo repositório: liyasthomas/colorbook
# Lendo repositório: cerner/terra-core
# Lendo repositório: llorentegerman/react-admin-dashboard
# Lendo repositório: johnpolacek/nextjs-mdx-blog-starter
# Lendo repositório: creativetimofficial/soft-ui-react-native
# Lendo repositório: viclafouch/mui-tel-input
# Lendo repositório: meta-magic/amexio.github.io
# Lendo repositório: fiffty/react-treeview-mui
# Lendo repositório: iqonicdesignofficial/hope-ui-design-system
# Lendo repositório: kaal-coder/hacktoberfest2023
# Lendo repositório: trendmicro-frontend/tonic-ui
# Lendo repositório: DevCloudFE/react-devui
# Lendo repositório: webpixels/css
# Lendo repositório: wle8300/uifx
# Lendo repositório: hmans/three-elements
# Lendo repositório: catherineisonline/pizza-time-with-react
# Lendo repositório: s-shemmee/TikTok-UI-Clone
# Lendo repositório: danielwuachin/nextjs-animations
# Lendo repositório: jpvalery/newfoundland
# Lendo repositório: aws/aws-northstar
# Lendo repositório: trailheadapps/az-insurance
# Lendo repositório: telekom/scale
# Lendo repositório: siemens/ix
# Lendo repositório: Scrivito/scrivito_example_app_js
# Lendo repositório: digitalnsw/nsw-design-system
# Lendo repositório: Tobijudah/york-and-dante
# Lendo repositório: adobe/adobe-dx
# Lendo repositório: 18F/guides
# Lendo repositório: solidjs/solid
# Lendo repositório: quasarframework/quasar
# Lendo repositório: slint-ui/slint
# Lendo repositório: infernojs/inferno
# Lendo repositório: kbrsh/moon
# Lendo repositório: day8/re-frame
# Lendo repositório: containers/podman-desktop
# Lendo repositório: redom/redom
# Lendo repositório: capricorn86/happy-dom
# Lendo repositório: jekyll/jekyll-admin
# Lendo repositório: pmndrs/uikit
# Lendo repositório: open-source-labs/Svelvet
# Lendo repositório: mosch/react-avatar-editor
# Lendo repositório: gabrielrcouto/php-gui
# Lendo repositório: vinibiavatti1/TuiCss
# Lendo repositório: SAP/ui5-webcomponents
# Lendo repositório: antonmedv/monkberry
# Lendo repositório: mgmeyers/obsidian-style-settings
# Lendo repositório: Zerx0r/Kage
# Lendo repositório: d3ward/toolz
# Lendo repositório: dyo/dyo
# Lendo repositório: zircleUI/zircleUI
# Lendo repositório: dec0dOS/zero-ui
# Lendo repositório: garbles/yolk
# Lendo repositório: eduardolat/pgbackweb
# Lendo repositório: elix/elix
# Lendo repositório: rphlr/42-Evals
# Lendo repositório: nextapps-de/mikado
# Lendo repositório: grammarly/focal
# Lendo repositório: pengxiaotian/datav-vue
# Lendo repositório: phibr0/obsidian-commander
# Lendo repositório: neo4j/neo4j-browser
# Lendo repositório: MishanPoudel/Windows11-3.0
# Lendo repositório: MohmmedAshraf/laravel-translations
# Lendo repositório: ekvedaras/redis-gui
# Lendo repositório: shamansir/rpd
# Lendo repositório: bem/bem-react
# Lendo repositório: Famous/framework
# Lendo repositório: Authman2/Mosaic
# Lendo repositório: solidjs-community/solid-aria
# Lendo repositório: arunbandari/mongo-gui
# Lendo repositório: rdub80/aframe-gui
# Lendo repositório: kor-ui/kor
# Lendo repositório: obsfx/libgen-downloader
# Lendo repositório: ioanmo226/chatgpt-web-application
# Lendo repositório: wfp/designsystem
# Lendo repositório: sauzy34/react-native-multi-selectbox
# Lendo repositório: itchief/ui-components
# Lendo repositório: jhipster/jhipster-online
# Lendo repositório: strveJs/strve
# Lendo repositório: SAP/fundamental-styles
# Lendo repositório: awesome-yasin/PDF-Verse
# Lendo repositório: smallcase/react-native-simple-biometrics
# Lendo repositório: oslabs-beta/Ahoy
# Lendo repositório: tableaunoir/tableaunoir
# Lendo repositório: microsoft/react-dag-editor
# Lendo repositório: owsolutions/angular5-iot-dashboard
# Lendo repositório: freedomofpress/sunder
# Lendo repositório: feathersui/feathersui-openfl
# Lendo repositório: starknet-io/starkgate-frontend
# Lendo repositório: louh/lcars
# Lendo repositório: SolidOS/solid-ui
# Lendo repositório: hggeorgiev/CentroUI
# Lendo repositório: openfext/vue-admin-next
# Lendo repositório: DSpace/dspace-angular
# Lendo repositório: AXeL-dev/distract-me-not
# Lendo repositório: snapcrunch/electron-preferences
# Lendo repositório: eraeco/joy
# Lendo repositório: wikimedia/WikimediaUI-Style-Guide
# Lendo repositório: RocketCommunicationsInc/astro
# Lendo repositório: red-ninjas/himalaya-ui
# Lendo repositório: openware/baseapp
# Lendo repositório: LiskArchive/lisk-mobile
# Lendo repositório: hamzasaleem2/s3oosh
# Lendo repositório: forcedotcom/SFDX-Data-Move-Utility-Desktop-App
# Lendo repositório: HimanshuNarware/CareerZunction_Intern
# Lendo repositório: karloespiritu/bemskel
# Lendo repositório: build-security/react-rbac-ui-manager
# Lendo repositório: dckiller51/lovelace-body-miscale-card
# Lendo repositório: TokenMarketNet/ethereum-smart-contract-transaction-demo
# Lendo repositório: solana-nft-programs/staking-ui
# Lendo repositório: aclap-dev/jocly
# Lendo repositório: wikimedia/design-codex
# Lendo repositório: Clipteam/clipcc-gui
# Lendo repositório: openbmc/webui-vue
# Lendo repositório: Daynnnnn/soketi-ui
# Lendo repositório: mendix/Atlas-UI-Framework
# Lendo repositório: EasyDynamics/oscal-react-library
# Lendo repositório: moja-global/FLINT-UI
# Lendo repositório: iamfaiz/react-auth-ui
# Lendo repositório: laminas/laminas-config
# Lendo repositório: datarhei/restreamer-ui
# Lendo repositório: spartez/vue-aui
# Lendo repositório: react-navigation/react-navigation
# Lendo repositório: wix/react-native-navigation
# Lendo repositório: Mango/slideout
# Lendo repositório: redfin/react-server
# Lendo repositório: airbnb/native-navigation
# Lendo repositório: software-mansion/react-native-screens
# Lendo repositório: fram-x/FluidTransitions
# Lendo repositório: tgrosinger/advanced-tables-obsidian
# Lendo repositório: azouaoui-med/react-pro-sidebar
# Lendo repositório: orchidjs/tom-select
# Lendo repositório: roninoss/create-expo-stack
# Lendo repositório: IjzerenHein/react-navigation-shared-element
# Lendo repositório: t4t5/react-native-router
# Lendo repositório: benevbright/react-navigation-collapsible
# Lendo repositório: zack24q/vue-navigation
# Lendo repositório: expo/ex-navigation
# Lendo repositório: GetStream/stream-chat-react-native
# Lendo repositório: torgeadelin/react-native-animated-nav-tab-bar
# Lendo repositório: vonovak/react-navigation-header-buttons
# Lendo repositório: TerryZ/SelectPage
# Lendo repositório: hezhongfeng/vue-page-stack
# Lendo repositório: timomeh/react-native-material-bottom-navigation
# Lendo repositório: nihgwu/react-native-dva-starter
# Lendo repositório: wix-incubator/react-native-controllers
# Lendo repositório: grahammendick/navigation
# Lendo repositório: react-navigation/hooks
# Lendo repositório: craftedbygc/taxi
# Lendo repositório: kanzitelli/rnn-starter
# Lendo repositório: oleksiikhr/vue-stripe-menu
# Lendo repositório: ardaogulcan/react-native-keyboard-accessory
# Lendo repositório: winoteam/react-router-navigation
# Lendo repositório: react-navigation/navigation-ex
# Lendo repositório: spatie/laravel-navigation
# Lendo repositório: infinitered/ignite-andross
# Lendo repositório: hoaphantn7604/react-native-curved-bottom-bar
# Lendo repositório: plmok61/react-navigation-transitions
# Lendo repositório: nandorojo/expo-next-react-navigation
# Lendo repositório: kanzitelli/expo-starter
# Lendo repositório: vonovak/react-navigation-props-mapper
# Lendo repositório: react-navigation/stack
# Lendo repositório: anhquan291/e-commerce-app-react-native
# Lendo repositório: DeepNotesApp/DeepNotes
# Lendo repositório: nandorojo/react-navigation-heavy-screen
# Lendo repositório: jlyman/RN-NavigationExperimental-Redux-Example
# Lendo repositório: wmira/react-sidenav
# Lendo repositório: react-navigation/tabs
# Lendo repositório: listenzz/hybrid-navigation
# Lendo repositório: Purii/react-use-scrollspy
# Lendo repositório: NoriginMedia/Norigin-Spatial-Navigation
# Lendo repositório: VirtusLab-Open-Source/strapi-plugin-navigation
# Lendo repositório: lcdsantos/menuspy
# Lendo repositório: wataru-maeda/react-native-boilerplate
# Lendo repositório: react-navigation/redux-helpers
# Lendo repositório: nandorojo/swr-react-native
# Lendo repositório: AmitM30/react-native-typescript-boilerplate
# Lendo repositório: laravelista/Ekko
# Lendo repositório: thebylito/react-native-navigation-bar-color
# Lendo repositório: atoami/react-native-navigation-redux-starter-kit
# Lendo repositório: kadiraydinli/react-native-system-navigation-bar
# Lendo repositório: jineshshah36/react-native-nav
# Lendo repositório: Nubescope/react-native-navigation-hooks
# Lendo repositório: AlexGladkov/Odyssey
# Lendo repositório: n1crack/vuefinder
# Lendo repositório: walljser/community_e_commerce
# Lendo repositório: AshleyLv/vue-quick-menu
# Lendo repositório: GetStream/slack-clone-react-native
# Lendo repositório: lukebrandonfarrell/react-native-navigation-drawer-extension
# Lendo repositório: NigelOToole/priority-nav-scroller
# Lendo repositório: bamlab/react-tv-space-navigation
# Lendo repositório: vonovak/react-navigation-backhandler
# Lendo repositório: chabou/hyper-pane
# Lendo repositório: entria/ReactNavigationRelayModern
# Lendo repositório: Traviskn/react-router-native-stack
# Lendo repositório: peter-mach/react-navigation-is-focused-hoc
# Lendo repositório: homeeondemand/react-native-mapbox-navigation
# Lendo repositório: J3-Tech/Vue-Tree-Navigation
# Lendo repositório: sergeyshpadyrev/react-native-easy-router
# Lendo repositório: surjithctly/astro-navbar
# Lendo repositório: parksben/markdown-navbar
# Lendo repositório: Mindinventory/react-native-navigation-animation
# Lendo repositório: shubhnik/redux-react-navigation-demos
# Lendo repositório: starters-dev/rn-starter
# Lendo repositório: react-navigation/drawer
# Lendo repositório: dpa99c/react-native-launch-navigator
# Lendo repositório: ipeedy/react-native-boilerplate
# Lendo repositório: jeneser/vue-scroll-behavior
# Lendo repositório: xiaogliu/react-native-complete-demo
# Lendo repositório: flyandi/react-native-maps-navigation
# Lendo repositório: Upstatement/react-router-guards
# Lendo repositório: verbb/cp-nav
# Lendo repositório: kybarg/bootstrap-dropdown-hover
# Lendo repositório: bithoven-dev/ReactNavigationAuthenticationFlowsWithHooks
# Lendo repositório: zq99299/gitbook-plugin-anchor-navigation-ex
# Lendo repositório: mrcrmn/docc
# Lendo repositório: react-navigation/search-layout
# Lendo repositório: ionicthemes/ionic4-starter-app-tutorial
# Lendo repositório: handi-dev/react-native-boilerplate
# Lendo repositório: microsoft/tabster
# Lendo repositório: svbutko/react-native-template-strong
# Lendo repositório: puti94/RNExample
# Lendo repositório: benawad/react-navigation-v5-tutorial
# Lendo repositório: solygambas/react-native-shopping-app
# Lendo repositório: wojteg1337/MobXApp
# Lendo repositório: jic999/moon-web-start
# Lendo repositório: frontend-joe/react-sidebars
# Lendo repositório: 11ty/eleventy-navigation
# Lendo repositório: dailydrip/react-native-navigation-sample
# Lendo repositório: bbc/lrud
# Lendo repositório: lewhunt/react-tv-player
# Lendo repositório: gxsshallot/react-native-pure-navigation-bar
# Lendo repositório: proshoumma/Book-of-Spices
# Lendo repositório: react-navigation/web
# Lendo repositório: aijason/RN_WanAndroid
# Lendo repositório: ModusCreateOrg/react-navigation-redux-sample
# Lendo repositório: verbb/navigation
# Lendo repositório: m-danish-iqbal/section-scroll
# Lendo repositório: chacestew/react-router-tabs
# Lendo repositório: SashenJayathilaka/Deliveroo-Clone
# Lendo repositório: guangqiang-liu/react-navigation-demo
# Lendo repositório: ionicthemes/ionic5-starter-app-tutorial
# Lendo repositório: evoluhq/evolu
# Lendo repositório: tywalch/electrodb
# Lendo repositório: shannonhochkins/ha-component-kit
# Lendo repositório: thepassle/generic-components
# Lendo repositório: qossmic/rich-model-forms-bundle
# Lendo repositório: TimMikeladze/typescript-react-package-starter
# Lendo repositório: jpmorganchase/salt-ds
# Lendo repositório: FusionWowCMS/FusionCMS
# Lendo repositório: Keyrxng/Testnet-wallet-drainer
# Lendo repositório: BorisKozo/react-datatables
# Lendo repositório: disco-oauth/disco-oauth
# Lendo repositório: AxisCommunications/practical-react-components
# Lendo repositório: BranchMetrics/react-native-branch-deep-linking-attribution
# Lendo repositório: HaikuTeam/animator
# Lendo repositório: HEmile/juggl
# Lendo repositório: FightingDesign/fighting-design
# Lendo repositório: tsalb/lwc-utils
# Lendo repositório: googlecreativelab/posenet-sketchbook
# Lendo repositório: BrandonArmand/Binari
# Lendo repositório: duan602728596/antd-schema-form
# Lendo repositório: ApoorvSaxena/colordrop
# Lendo repositório: tcbutler320/Jekyll-Theme-Dumbarton
# Lendo repositório: evrone/postcss-px-to-viewport
# Lendo repositório: Figma-Linux/figma-linux
# Lendo repositório: sakofchit/system.css
# Lendo repositório: beercss/beercss
# Lendo repositório: LeCoupa/vuedarkmode
# Lendo repositório: iTwin/iTwinUI
# Lendo repositório: joshrps/laravel-shopify-API-wrapper
# Lendo repositório: publiclab/PublicLab.Editor
# Lendo repositório: JC-Coder/startease
# Lendo repositório: Defcon27/Real-Estate-Management-System-using-NodeJS-Express-MongoDB
# Lendo repositório: wework/ray
# Lendo repositório: hacktheme/Nice-Admin
# Lendo repositório: xxxily/h5player
# Lendo repositório: 1943time/inkdown
# Lendo repositório: mohammad-mghn/wins-11
# Lendo repositório: faouzioudouh/react-tracker
# Lendo repositório: wumke/react-native-immediate-phone-call
# Lendo repositório: jlyman/react-native-rating-requestor
# Lendo repositório: sunpietro/dragster
# Lendo repositório: facebook/react-native
# Lendo repositório: styled-components/styled-components
# Lendo repositório: dcloudio/uni-app
# Lendo repositório: marmelab/react-admin
# Lendo repositório: NativeScript/NativeScript
# Lendo repositório: payloadcms/payload
# Lendo repositório: rahuldkjain/github-profile-readme-generator
# Lendo repositório: nikitavoloboev/config
# Lendo repositório: you-dont-need/You-Dont-Need-Lodash-Underscore
# Lendo repositório: filamentphp/filament
# Lendo repositório: tabler/tabler-icons
# Lendo repositório: ReVanced/revanced-manager
# Lendo repositório: beekeeper-studio/beekeeper-studio
# Lendo repositório: tusen-ai/naive-ui
# Lendo repositório: diegomura/react-pdf
# Lendo repositório: froala/design-blocks
# Lendo repositório: krasimir/react-in-patterns
# Lendo repositório: piotrwitek/react-redux-typescript-guide
# Lendo repositório: you-dont-need/You-Dont-Need-Momentjs
# Lendo repositório: vuejs/pinia
# Lendo repositório: Chocobozzz/PeerTube
# Lendo repositório: graphql/dataloader
# Lendo repositório: formkit/auto-animate
# Lendo repositório: redux-form/redux-form
# Lendo repositório: louislam/dockge
# Lendo repositório: firebase/functions-samples
# Lendo repositório: jamiebuilds/babel-handbook
# Lendo repositório: erikras/react-redux-universal-hot-example
# Lendo repositório: luin/medis
# Lendo repositório: ptmt/react-native-macos
# Lendo repositório: connors/photon
# Lendo repositório: vuematerial/vue-material
# Lendo repositório: oblador/react-native-animatable
# Lendo repositório: FormidableLabs/spectacle
# Lendo repositório: organicmaps/organicmaps
# Lendo repositório: aws-amplify/amplify-js
# Lendo repositório: i18next/react-i18next
# Lendo repositório: facebookarchive/react-360
# Lendo repositório: mertJF/tailblocks
# Lendo repositório: developit/htm
# Lendo repositório: react-native-image-picker/react-native-image-picker
# Lendo repositório: GeekyAnts/vue-native-core
# Lendo repositório: CorentinTh/it-tools
# Lendo repositório: reown-com/appkit
# Lendo repositório: adrianhajdin/project_modern_ui_ux_gpt3
# Lendo repositório: adrianhajdin/project_hoobank
# Lendo repositório: nikgraf/belle
# Lendo repositório: sanniassin/react-input-mask
# Lendo repositório: KlausSchaefers/quant-ux
# Request GET /repos/KlausSchaefers/quant-ux/contents/babel.config.js failed with 403: Forbidden
# Setting next backoff to 1245.052687s
# Lendo repositório: antares-sql/antares
# Lendo repositório: mCaptcha/mCaptcha
# Lendo repositório: adrianhajdin/project_modern_ui_ux_restaurant
# Lendo repositório: neon-age/Smart-Inspector
# Lendo repositório: fgr-araujo/vue-shortkey
# Lendo repositório: foundry-rs/forge-std
# Lendo repositório: Temzasse/react-modal-sheet
# Lendo repositório: hicetnunc2000/hicetnunc
# Lendo repositório: wellyshen/react-cool-img
# Lendo repositório: adrianhajdin/travel_ui_ux
# Lendo repositório: Voxelum/x-minecraft-launcher
# Lendo repositório: sonnylazuardi/react-native-nike-running
# Lendo repositório: 6eDesign/svelte-calendar
# Lendo repositório: AudiusProject/hedgehog
# Lendo repositório: okta/okta-signin-widget
# Lendo repositório: mrk-us/sketchsheets
# Lendo repositório: evmts/tevm-monorepo
# Lendo repositório: hirbod/react-native-volume-manager
# Lendo repositório: sejr/react-messenger
# Lendo repositório: mblarsen/vue-browser-acl
# Lendo repositório: bbc/html5-video-compositor
# Lendo repositório: rdkcentral/Lightning
# Lendo repositório: rfmiotto/react-use-draggable-scroll
# Lendo repositório: aurelia/app-ux-showcase
# Lendo repositório: Govind783/react-e-commerce-
# Lendo repositório: EttaWallet/EttaWallet
# Lendo repositório: hkxicor/uber-clone-react-native
# Lendo repositório: storybookjs/storybook
# Lendo repositório: ChatGPTNextWeb/ChatGPT-Next-Web
# Lendo repositório: ElemeFE/element
# Lendo repositório: vuejs/core
# Lendo repositório: tabler/tabler
# Lendo repositório: chakra-ui/chakra-ui
# Lendo repositório: TanStack/table
# Lendo repositório: react-native-elements/react-native-elements
# Lendo repositório: element-plus/element-plus
# Lendo repositório: iview/iview
# Lendo repositório: youzan/vant
# Lendo repositório: nextui-org/nextui
# Lendo repositório: necolas/react-native-web
# Lendo repositório: palantir/blueprint
# Lendo repositório: GeekyAnts/NativeBase
# Lendo repositório: microsoft/fluentui
# Lendo repositório: alibaba/weex
# Lendo repositório: airyland/vux
# Lendo repositório: Lissy93/dashy
# Lendo repositório: FaridSafi/react-native-gifted-chat
# Lendo repositório: Semantic-Org/Semantic-UI-React
# Lendo repositório: segmentio/evergreen
# Lendo repositório: ant-design/ant-design-mobile
# Lendo repositório: tamagui/tamagui
# Lendo repositório: atherosai/ui
# Lendo repositório: udecode/plate
# Lendo repositório: primefaces/primeng
# Lendo repositório: primefaces/primevue
# Lendo repositório: markmead/hyperui
# Lendo repositório: astrit/css.gg
# Lendo repositório: buefy/buefy
# Lendo repositório: gabrielbull/react-desktop
# Lendo repositório: uidotdev/usehooks
# Lendo repositório: mdbootstrap/material-design-for-bootstrap
# Lendo repositório: didi/cube-ui
# Lendo repositório: appbaseio/dejavu
# Lendo repositório: rebassjs/rebass
# Lendo repositório: styled-system/styled-system
# Lendo repositório: themesberg/flowbite
# Lendo repositório: yang991178/fluent-reader
# Lendo repositório: arwes/arwes
# Lendo repositório: ChenYilong/CYLTabBarController
# Lendo repositório: primefaces/primereact
# Lendo repositório: react95-io/React95
# Lendo repositório: wix/react-native-ui-lib
# Lendo repositório: elastic/eui
# Lendo repositório: angular/flex-layout
# Lendo repositório: jpush/aurora-imui
# Lendo repositório: mob-sakai/UIEffect
# Lendo repositório: TanStack/virtual
# Lendo repositório: devias-io/material-kit-react
# Lendo repositório: komodorio/helm-dashboard
# Lendo repositório: appbaseio/reactivesearch
# Lendo repositório: searchkit/searchkit
# Lendo repositório: apache/incubator-weex-ui
# Lendo repositório: htmlstreamofficial/preline
# Lendo repositório: unovue/shadcn-vue
# Lendo repositório: firebase/firebaseui-web
# Lendo repositório: elementalui/elemental
# Lendo repositório: nuxt/ui
# Lendo repositório: vanjs-org/van
# Lendo repositório: ixartz/SaaS-Boilerplate
# Lendo repositório: frejs/fre
# Lendo repositório: czy0729/Bangumi
# Lendo repositório: JetBrains/ring-ui
# Lendo repositório: fomantic/Fomantic-UI
# Lendo repositório: mbrn/material-table
# Lendo repositório: konstaui/konsta
# Lendo repositório: Pagedraw/pagedraw
# Lendo repositório: React95/React95
# Lendo repositório: wangdahoo/vonic
# Lendo repositório: MarsX-dev/floatui
# Lendo repositório: mrzachnugent/react-native-reusables
# Lendo repositório: hug-sun/element3
# Lendo repositório: taiga-family/taiga-ui
# Lendo repositório: ElementUI/element-starter
# Lendo repositório: FormidableLabs/nuka-carousel
# Lendo repositório: hybridsjs/hybrids
# Lendo repositório: premieroctet/openchakra
# Lendo repositório: Shopify/restyle
# Lendo repositório: rilyu/teaset
# Lendo repositório: rcaferati/react-awesome-slider
# Lendo repositório: mantinedev/ui.mantine.dev
# Lendo repositório: kubernetes-sigs/kui
# Lendo repositório: vantezzen/auto-form
# Following Github server redirection from /repos/vantezzen/auto-form to /repositories/669080455
# Lendo repositório: Dashibase/lotion
# Lendo repositório: astoilkov/jsblocks
# Lendo repositório: gregnb/mui-datatables
# Lendo repositório: view-design/ViewUI
# Lendo repositório: homebridge/homebridge-config-ui-x
# Lendo repositório: heyui/heyui
# Lendo repositório: horizon-ui/horizon-ui-chakra
# Lendo repositório: cjcenizal/flexbox-patterns
# Lendo repositório: uidotdev/react-course
# Lendo repositório: siriwatknp/mui-treasury
# Lendo repositório: minimal-ui-kit/material-kit-react
# Lendo repositório: Kiranism/next-shadcn-dashboard-starter
# Lendo repositório: AT-UI/at-ui
# Lendo repositório: nirsky/react-native-size-matters
# Lendo repositório: tabler/tabler-react
# Lendo repositório: youzan/zent
# Lendo repositório: OnedocLabs/react-print-pdf
# Lendo repositório: tuandm/laravue
# Lendo repositório: vidstack/player
# Lendo repositório: GeekyAnts/NativeBase-KitchenSink
# Lendo repositório: jesec/flood
# Lendo repositório: alfonsobries/vue-tailwind
# Lendo repositório: DevExpress/devextreme-reactive
# Lendo repositório: nachos-ui/nachos-ui
# Lendo repositório: vasturiano/globe.gl
# Lendo repositório: mob-sakai/SoftMaskForUGUI
# Lendo repositório: ivan-lednev/obsidian-day-planner
# Lendo repositório: nandorojo/dripsy
# Lendo repositório: rogden/tailwind-config-viewer
# Lendo repositório: elastic/search-ui
# Lendo repositório: hellof2e/quark-design
# Lendo repositório: dunky11/react-saas-template
# Lendo repositório: lsqy/taro-music
# Lendo repositório: parro-it/libui-node
# Lendo repositório: layerJS/layerJS
# Lendo repositório: fwouts/previewjs
# Lendo repositório: beekai-oss/react-simple-animate
# Lendo repositório: Flood-UI/flood
# Lendo repositório: rgossiaux/svelte-headlessui
# Lendo repositório: suyalcinkaya/onur.dev
# Lendo repositório: kuma-ui/kuma-ui
# Lendo repositório: bpatrik/pigallery2
# Lendo repositório: vexip-ui/vexip-ui
# Lendo repositório: DesignRevision/shards-ui
# Lendo repositório: Tencent/QMUI_Web
# Lendo repositório: web3ui/web3uikit
# Lendo repositório: CzBiX/qb-web
# Lendo repositório: flatlogic/react-material-admin
# Lendo repositório: opentiny/tiny-vue
# Lendo repositório: smooth-code/smooth-ui
# Lendo repositório: chenz24/vue-blu
# Lendo repositório: raphamorim/react-ape
# Lendo repositório: BlazeSoftware/atoms
# Lendo repositório: vum-team/vum
# Lendo repositório: hauptrolle/chakra-templates
# Lendo repositório: purescript-halogen/purescript-halogen
# Lendo repositório: matyunya/smelte
# Lendo repositório: influxdata/chronograf
# Lendo repositório: react-native-picker/picker
# Lendo repositório: KevinVandy/material-react-table
# Lendo repositório: vuikit/vuikit
# Lendo repositório: adrianhajdin/project_corona_tracker
# Lendo repositório: timothymiller/t4-app
# Lendo repositório: LekoArts/gatsby-starter-portfolio-cara
# Lendo repositório: scottie1984/swagger-ui-express
# Lendo repositório: BootstrapDash/StarAdmin-Free-Bootstrap-Admin-Template
# Lendo repositório: ikun-svelte/ikun-ui
# Lendo repositório: kirevdokimov/Unity-UI-Rounded-Corners
# Lendo repositório: adrianhajdin/project_youtube_clone
# Lendo repositório: Raathigesh/retoggle
# Lendo repositório: raunofreiberg/ui-playbook
# Lendo repositório: Leecason/element-tiptap
# Lendo repositório: vuejs/ui
# Lendo repositório: 3lang3/react-vant
# Lendo repositório: max-mapper/yo-yo
# Lendo repositório: saas-js/saas-ui
# Lendo repositório: creativetimofficial/notus-nextjs
# Lendo repositório: djenriquez/vault-ui
# Lendo repositório: rcaferati/react-awesome-button
# Lendo repositório: chatscope/chat-ui-kit-react
# Lendo repositório: sailboatui/sailboatui
# Lendo repositório: rcaferati/react-native-really-awesome-button
# Lendo repositório: adrianhajdin/social_media_app
# Lendo repositório: Detaysoft/react-chat-elements
# Lendo repositório: TailAdmin/tailadmin-free-tailwind-dashboard-template
# Lendo repositório: Equal-UI/Equal
# Lendo repositório: Tencent/tdesign-miniprogram
# Lendo repositório: XboxYan/xy-ui
# Lendo repositório: playbook-ui/playbook-ios
# Lendo repositório: jsartisan/react-native-magnus
# Lendo repositório: anubra266/choc-ui
# Lendo repositório: mehdibha/dotUI
# Lendo repositório: cferdinandi/reef
# Lendo repositório: oruga-ui/oruga
# Lendo repositório: karthikmudunuri/eldoraui
# Lendo repositório: danmindru/page-ui
# Lendo repositório: atef-najar/react-native-shop-ui
# Lendo repositório: Microwawe/mamba-ui
# Lendo repositório: segmentio/ui-box
# Lendo repositório: Aashu-Dubey/React-Native-UI-Templates
# Lendo repositório: TailGrids/tailwind-ui-components
# Lendo repositório: dmvaldman/samsara
# Lendo repositório: luwes/sinuous
# Lendo repositório: peggyrayzis/react-native-create-bridge
# Lendo repositório: njleonzhang/vue-data-tables
# Lendo repositório: N3-components/N3-components
# Lendo repositório: rvpanoz/luna
# Lendo repositório: blefnk/relivator-nextjs-template
# Lendo repositório: reflexjs/reflexjs
# Lendo repositório: vladotesanovic/ngSemantic
# Lendo repositório: stackworx/formik-mui
# Lendo repositório: zwave-js/zwave-js-ui
# Lendo repositório: microsoftgraph/microsoft-graph-toolkit
# Lendo repositório: appbaseio/reactivemaps
# Lendo repositório: fahad19/proppy
# Lendo repositório: nuxt/modules
# Lendo repositório: Semantic-UI-Vue/Semantic-UI-Vue
# Lendo repositório: themesberg/volt-react-dashboard
# Lendo repositório: uilibrary/matx-react
# Lendo repositório: gdotdesign/elm-ui
# Lendo repositório: totumonline/totum-mit
# Lendo repositório: lio-mengxiang/mx-design
# Lendo repositório: trufflesuite/drizzle
# Lendo repositório: myliang/fish-ui
# Lendo repositório: hsuanyi-chou/shadcn-ui-expansions
# Lendo repositório: surveyjs/survey-creator
# Lendo repositório: dracula/dracula-ui
# Lendo repositório: aws-amplify/amplify-ui
# Lendo repositório: themefisher/sleek-bootstrap
# Lendo repositório: DTStack/molecule
# Lendo repositório: jdf2e/nutui-react
# Lendo repositório: microsoft/ace
# Lendo repositório: themesberg/neumorphism-ui-bootstrap
# Lendo repositório: robbins23/daisyui-admin-dashboard-template
# Lendo repositório: oku-ui/primitives
# Lendo repositório: angular-split/angular-split
# Lendo repositório: ant-design/ant-design-web3
# Lendo repositório: ComponentDriven/csf
# Lendo repositório: erikras/redux-form-material-ui
# Lendo repositório: creativetimofficial/notus-svelte
# Lendo repositório: Tencent/tdesign-react
# Lendo repositório: vue-terminal/vue-termui
# Lendo repositório: sozonome/nextarter-chakra
# Lendo repositório: alexanmtz/material-sense
# Lendo repositório: creativetimofficial/notus-react
# Lendo repositório: fancyapps/ui
# Lendo repositório: dropbox/scooter
# Lendo repositório: Just-Moh-it/Pckd
# Lendo repositório: remix-run/remix
# Lendo repositório: adobe/react-spectrum
# Lendo repositório: Atyantik/react-pwa
# Lendo repositório: divriots/jampack
# Lendo repositório: felixpalmer/procedural-gl-js
# Lendo repositório: gorilla-devs/GDLauncher
# Lendo repositório: yiliansource/party-js
# Lendo repositório: kanriapp/kanri
# Lendo repositório: ember-engines/ember-engines
# Lendo repositório: jsuites/jsuites
# Lendo repositório: ozntel/file-tree-alternative
# Lendo repositório: SAP/ui5-webcomponents-react
# Lendo repositório: dot-cafe/beam.cafe
# Lendo repositório: khmyznikov/pwa-install
# Lendo repositório: graphcommerce-org/graphcommerce
# Lendo repositório: pixijs/pixi-ui
# Lendo repositório: nisabmohd/ChatGPT
# Lendo repositório: numandev1/react-native-bottomsheet-reanimated
# Lendo repositório: FrontendMasters/remix-fundamentals
# Lendo repositório: leemonade/leemons
# Lendo repositório: FrontendMasters/advanced-remix
# Lendo repositório: SAP/btp-solution-diagrams
# Lendo repositório: ShaifArfan/AYANs-portfolio
# Lendo repositório: francoborrelli/spotify-react-web-client
# Lendo repositório: swisspost/design-system
# Lendo repositório: kondasoft/ks-bootshop
# Lendo repositório: supermedium/aframe-react
# Lendo repositório: ngokevin/aframe-react-boilerplate
# Lendo repositório: transferthought/transfer-thought
# Resultados salvos em: ../Database/Questao1\resultados.csv
