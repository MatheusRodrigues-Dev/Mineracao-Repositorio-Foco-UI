# %%
import pandas as pd

# Carregue a tabela
df = pd.read_csv('../Database/Resultados-Busca/repositorios_categorizados.csv')

# Formate as colunas "created_at" e "updated_at" como datas
df['created_at'] = pd.to_datetime(df['created_at'])
df['updated_at'] = pd.to_datetime(df['updated_at'])

# Formate as datas como "YYYY-MM-DD"
df['created_at'] = df['created_at'].dt.strftime('%Y-%m-%d')
df['updated_at'] = df['updated_at'].dt.strftime('%Y-%m-%d')

# Imprima a tabela formatada
print(df)

df.to_csv('../Database/Resultados-Busca/repositories.csv', index=False, sep=',', decimal=',')
# Out:
#                                   name  \
# 0                          XiaoMi/hiui
# 1                ant-design/ant-design
# 2                         Tencent/weui
# 3              tailwindlabs/headlessui
# 4          vueComponent/ant-design-vue
# ..                                 ...
# 701            swisspost/design-system
# 702              kondasoft/ks-bootshop
# 703           supermedium/aframe-react
# 704  ngokevin/aframe-react-boilerplate
# 705   transferthought/transfer-thought
#
#                                            description  stars    language  \
# 0    HIUI is a solution that is adequate for the fo...    736  TypeScript
# 1    An enterprise-class UI design language and Rea...  92123  TypeScript
# 2    A UI library by WeChat official design team, i...  27149        Less
# 3    Completely unstyled, fully accessible UI compo...  25890  TypeScript
# 4    🌈  An enterprise-class UI components based on ...  20169         Vue
# ..                                                 ...    ...         ...
# 701  The Swiss Post Design System pattern library f...    121        SCSS
# 702  Our Free Shopify Theme focused on simplicity, ...    115      Liquid
# 703  :atom: Build virtual reality experiences with ...   1420  JavaScript
# 704  :sunglasses: Boilerplate for building virtual ...    375  JavaScript
# 705  🔁Web platform for building virtual reality exp...    164  JavaScript
#
#      forks                                                url  created_at  \
# 0       99                     https://github.com/XiaoMi/hiui  2018-10-08
# 1    49269           https://github.com/ant-design/ant-design  2015-04-24
# 2     6408                    https://github.com/Tencent/weui  2014-12-18
# 3     1068         https://github.com/tailwindlabs/headlessui  2020-09-16
# 4     3787     https://github.com/vueComponent/ant-design-vue  2017-09-20
# ..     ...                                                ...         ...
# 701     14         https://github.com/swisspost/design-system  2022-02-23
# 702    107           https://github.com/kondasoft/ks-bootshop  2020-06-29
# 703    150        https://github.com/supermedium/aframe-react  2015-12-16
# 704    156  https://github.com/ngokevin/aframe-react-boile...  2015-12-16
# 705     12  https://github.com/transferthought/transfer-th...  2024-05-24
#
#      updated_at  open_issues default_branch  ...  package-lock.json  \
# 0    2024-10-08           89         master  ...              False
# 1    2024-10-12         1219         master  ...              False
# 2    2024-10-12           56         master  ...               True
# 3    2024-10-12           68           main  ...               True
# 4    2024-10-12          229           main  ...              False
# ..          ...          ...            ...  ...                ...
# 701  2024-10-11          218           main  ...              False
# 702  2024-10-09            4         master  ...              False
# 703  2024-09-27           43         master  ...               True
# 704  2024-08-16           21         master  ...              False
# 705  2024-09-17            0           main  ...               True
#
#      composer.json composer.lock  vite.config.js  angular.json  tsconfig.json  \
# 0            False         False           False         False           True
# 1            False         False           False         False           True
# 2            False         False           False         False          False
# 3            False         False           False         False          False
# 4            False         False           False         False           True
# ..             ...           ...             ...           ...            ...
# 701          False         False           False         False          False
# 702          False         False           False         False          False
# 703          False         False           False         False          False
# 704          False         False           False         False          False
# 705          False         False           False         False          False
#
#      babel.config.js  postcss.config.js  vue.config.js       category
# 0              False               True          False  Componente UX
# 1              False              False          False  Componente UX
# 2              False              False          False   Aplicação UX
# 3              False              False          False  Componente UX
# 4               True               True          False  Componente UX
# ..               ...                ...            ...            ...
# 701            False              False          False  Ferramenta UX
# 702            False              False          False  Componente UX
# 703            False              False          False  Componente UX
# 704            False              False          False  Componente UX
# 705             True              False           True   Aplicação UX
#
# [706 rows x 32 columns]
